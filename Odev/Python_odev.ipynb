# %% [markdown]
# # Python Kurulumu

# %% [markdown]
# 1.   Python Programlama Dilinin Kullanım Amaçları Nelerdir?
# 2.   Python programlama dilinin avantaj ve dezavantajları nelerdir?
# 3.   Python sisteme kurulum yaparken dikkat edilmesi gereken noktalar nelerdir?
# 4.   Ide (Integrated Development Environment - Entegre Geliştirme Ortamı) nedir? Python kodları yazarken hangi ideleri kullanabiliriz? Python ile beraber gelen Idenin adı nedir?
# 5.   interaktif shell nedir? hangi amaçlarla kullanılabilir?

# %% [markdown]
# # Bölüm 1 - Temel Giriş Konuları

# %% [markdown]
# 1.   print() fonksiyonun görevini açıklayınız.
# 2.   Kendizi tanıtan bir python programı yazınız. (En az 5 satır çıktı vermelidir)
# 3.   Yorum satırlar (Comment Line) nedir? hangi amaçlarla kullanılır? Kaç farklı şekilde yorum satırı yazılabilir örneklerle açıklayınız
# 4.   yorum satılarının ne olduğu konusunda çıktı veren ve yorum satırı barındıran bir program yazınız.
# 5.   Pythonda kullanılan temel veri tipleri nelerdir ? ilkel veri tipi olarakta adlandırılan bu veri tiplerini yorum satırları içeren bir programla örnek içerecek şekilde yazınız.
# 6.   type() fonksiyonunun görevini açıklayınız. type() fonksiyonu içerecek şekilde bir örnek yazınız.
# 7.   Değişken nedir? Hangi amaçla kullanılır? Değişken tanımlarken dikkat edilmesi gereken unsurları belirtiniz.
#
# 8.   Farklı veri tiplerine sahip değişkenler tanımlayarak bir program yazınız.
# 9.   Kendinizi tanıtan farklı veri tiplerine sahip verilerden oluşacak şekilde bir program yazınız.
# 10.  Çoklu değişken ataması nasıl yapılır örnek içeren bir program yazınız.
# 11. ![1.png](data:image/png;base64,...)

# %% [markdown]
# # Bölüm 2 - Veri Tipleri, Dönüşüm İşlemleri ve Girdi Çıktı İşlemleri

# %% [markdown]
# 1.   Kullanıcıdan veri almak için kullanılan fonksiyon nedir?
# 2.   Kullanıcıdan cevap alabileceğiniz basit bir tnışma programı yazınız.
# 3.   ilkel - temel veri tipleri arasında dönüşüm yapmak için kullanılan fonksiyonlar nelerdir?
# 4.   Tip dönüşümlerini içerecek şekilde bir program yazınız.
# 5.   Kullanıcıdan kendisini tanıtmasını istediğiniz ve aldığınız verileri çeşitli dönüşüm işlemlerine tabi tutarak kullanıcıya çeşitli çıktılar oluşturduğunuz bir program yazınız.
# 6.   Operatör kavramını açıklayınız.
# 7.   Pythonda bulunan Operatör türlerini, kullanılan operatörleri belirterek yazınız.
# 8.
# ```
# 2**5
# 5//2
# 4+3
# 11%3
# 5/2
# 2*5
# 3-5
# (4-1)**2
# (7//3)/2
# ```
#
#
# yukarıdaki işlemleri yaparak elde ettiğiniz sonuçarı sırasıyla yazdırınız.
# 9. ![2.png](data:image/png;base64,...)
# 10. ![3.png](data:image/png;base64,...)
# 11.
# ![4.png](data:image/png;base64,...)
# 12. id() fonksiyonunu açıklayınız.
# 13.
# ```
# Aşağıdaki kod nasıl bir çıktı üretir?
# a=10
# b=11
# c=12
# print (a is c)
# print (a is not b)
# a+=1
# print (a is b)
# a+=1
# print(a is c)
# ```

# %% [markdown]
# # Alıştırma Soruları

# %% [markdown]
# 1.   Bir öğrencinin matematik dersinden aldığı notlar sırasıyla 64, 86 ve 70’tir. Bu öğrencinin not ortalamasını hesaplayınız.
# 2.   Kullanıcıdan adını ve yaşını alarak adını yaşı kadar yazdıran programı yazınız.
# 3.   Dairenin alanını ve çevrenisi hesaplayan bir progrm yazınız. Pi değerini ve yarı çap değerini kullanıcıdan alınız.
# 4.   Kullanıcıdan doğum tarihini isteyerek ehliyet alma durumunu belirten programı yazınız.
# 5.   Kullanıcıdan faiz oranı ve para miktarını öğrenerek, girilen paranın yıllık faizini hesaplayan programı yazınız.
# 6.   Kullanıcıdan alacak olduğunuz veriler ile kullanıcının vücud kitle endeksini hesaplayan programı yazınız.
# 7.   kullanıcının sizinle adaş olup olmadığını yazdıran programı yazınız.
# 8.   Kullanıcıdan not ortalamasını isteyerek teşekkür, tadir alıp alamama durumunu yazdıran programı yazınız.
# 9.   Kullanıcıdan otoban uzunluğunu ve geçiş süresini isteyerek hızınız hesaplayınız. daha sonra kullanıcının hız cezası alıp almama durumunu yazdırınız.
# 10.  Yevmiyesi 350 TL olan bir işçinin çalışma gün sayısını öğrenerek, yevmiye tutarıı hesaplayan programı yazınız.

# %% [markdown]
# # Bolüm 3 - Koşullu ifadeler

# %% [markdown]
# *   1. Kullanıcıya memleketini sorarak hemşeri olup olmadığınızı yazdıran programı yazınız.
# *   2. Kullanıcıdan iki sayı isteyerek büyük olanı ve küçük olanı saırasıyla ekrana yazdıran uygulamayı yazınız.
# *   3. Kullanıcıdan 3 adet sayı isteyerek sayıları büyükten küçüğe sırayla yazdırınız.
# *   4. küşüye ehliyet için gerekli yaş ve eğitim sorularını sararak ehliyet alma durumunu yazdırınız (eğitim için ilkenaz ilköğretim mezunu olması gerekmektedir)
# *   5. Bir turnava düşünerek gerekli koşulları belirleyiniz. en az iki koşul olmak üzere kullanıcının turnuvaya katılıp katılmayacağı bilginizi veren programı yazınız.
# *   6. bir menü sipariş kontol sistemi yazınız. müşterinin menüsünün doğru olup olmadığını kontrol ediniz.(bir yiyecek ve içecek olmalı)
# *  7.  Hergün bir farklı bir mahalleye gidecek olan pazarlama elemanının, haftanın hangi gününde hangi mahallede olacak olduğunu söyleyen bir program yazınız.(elifli yapı)
# *   8. Kullanıcıdan üç adet oratalama isteyerek ders gerçeme durumunu yazdıran programı yazınız.
# *   9. Yukarıda ki soruya devam drumunu da ekleyerek geçme kalma durumunu belirtiniz.
# *   10. Kullanıcı adı ve şifre isteyerek doğru bilgileri girmesi halinde kullanıcıya hoşgeldin mesajı veren uygulamayı yazınız.
# *   11. Kullanıcının geçerli bir mail adresi girip girmediğini denetleyen bir program yazınız. (@ karakterinin varlığını kontrol ediniz)
# *   12. Kullanıcıya sevdiği programlama dilini sorarak, o programlama dilini geliştiren kişi(leri)n ismini yazıran programı yazınız. 4 adet yeterli
# *   13. Kullanıcıya seçtiği menüye göre fiyat bilgisi veren restoran uygulamasını yazınız.

# %% [markdown]
# # Bolum 4 - Döngüler (Aşağıda Bulunan Örnekleri Hem For hemde While Döngüsü İle Yazınız)

# %% [markdown]
# 1.   1-30 arasındaki tek sayıları yazdıran programı yazınız
# 2.   Girilen 10 Sayının Toplamını ve ortalamasını Bulan programı yazınız.
# 3.   Python 50’den 20(dahil ise)’ye kadar olan sayıları 3’er azaltarak ile ekrana yazdırınız.
# 4.   Girilen 20 sayıdan Tek ve Çift Sayıların Ortalamasını Hesaplattırarak ekrana yazdıran uygulamayı yazınız.
# 5.   Python ile iç içe For Döngüsü kullanarak 1′ den 10′ akadar çarpım tablosu oluşturunuz. (Yanyana çıktı veren versiyonunuda deneyiniz)
# 6.   Python ile iç içe while kullanarak 1′ den 10′ akadar çarpım tablosu oluşturunuz. (Yanyana çıktı veren versiyonunuda deneyiniz)
# 7.  Kullanıcıdan 2 kez aynı parolayı girmesini isteyerek, iki defa aynı parola girildiğinde giriş yapan farklı girildiğinde uyaran kodları oluşturun?
# 8.  Python 100'e kadar 3'e ve 5'e Tam Bölünen Sayıları Listeleyen Örnek yazınız
# 9.  "*" kullanarak 4*4 bir kare olşturunuz.
# 10. "*" kullanarak kullanıcının belirlediği ölçülerde bir dikdörtgen oluşturunuz.
# 11. iç içe döngüler kullanarak piramit belirlediğiniz yükseklikte pramitler oluşturunuz. Örnek kod aşağıda vardır.
# ```
# satir=10
# print('\n...Python Yıldızı...\n')
# for i in range(satir):
#     print(' '*(satir-i-1) + '*'*(2*i+1))
# ```
# 12.  Break deyiminin kullanımı görmek açısından 1'den 100' e kadar sayıları ekrana yazdırırken, her sayıyı kontrol edelim ve eğer sayı 35 ise döngüden çıkalım.
# 13.   Şimdi kullanıcıya bir sayı girmesini isteyelim ve break komutu kullanarak 1den kullanıcının girdiği sayıya kadar olan sayıları ekrana yazdıralım.while ile sonsuz döngü oluşturunuz.
# 14.   Birlikte sayı bulmaca yapalım.  sayimiz isimli bir değişken tanımlayıp, 1 ile 100 arasında istediğimiz bir sayıyı o değişkene atayalım. Ve kullanıcıya bir sayı girmesini isteyelim. Kullanıcı tuttuğumuz sayıyı yanlış girdiğinde "Yanlış, Bir kez daha dene!" mesajını ekrana yazdıralım. Doğru sayıyı girdiğinde ise ekrana "Tebrikler Kazandınız" şeklinde bir uyarı mesajı yazdıralım.
# 15. yukarıdaki örneği yönlendirme ile yaptırınız. (daha büyük sayı giriniz veya daha küçük sayı giriniz şeklinde)
# 16.   Python 100'e kadar 3'e ve 5'e Tam Bölünen Sayılar harici sayıları Listeleyen Örnek yazınız
# 17.  Kullanıcıdan 10 sayı girmesini ve girilen sayıların faktöriyel değerlerini toplamasını isteyinizisteyiniz. negatif bir sayı girildiğinde sayı isteme işlemini bitirerek girilen toplam sayı adetini ve elde edilen toplamı kullanıcıya yazdırırken, 7 ve katları sayılar girildiğinde gerekli hesaplamaları yapmayarak devam eden uygulamayı yazınız.
# 18. Girilen iki sayının ebob ve ekok değerlerini bulup yazdıran programı yazınız.
# 19.  Python ile girilen sayının basamak sayısını bulan kodu yazınız.
# 20.  Bir sayının, tüm basamaklarındaki rakamların sayının basamak katına toplamı kendisine eşit olan sayılara Armstrong sayısı denir. Örneğin; 407 sayısını ele alalım. 407’yi rakamlarına ayıralım. Sonrasında da bu rakamları, sayı üç haneli olduğu için rakamların küplerini alıp toplayalım:
#
# 407 ➡️ (43) + (03) + (73) = 407 yapmaktadır. Yani bu demektir ki 407 sayısı Armstrong bir sayıdır. Şimdi bunu Python ile kodlayınız.
# 21.   1000'e kadar olan Armstrong sayılarını yazdırınız.
# 22.   kullanıcıya 10 hak vererek Armstrong sayısını oluşturup oluşturamadığını test ediniz.

# %% [markdown]
# # Bolum 5 - Koleksiyonlar (List - Tuple - Set - Dict)

# %% [markdown]
# 1.   Bir menü programı oluşturunuz. (kategori ve yemek alt kategorileri tanımlayarak)
# 2.   Yukarıdaki örneği fiyatlı yemeklerin fiyatları olacak şekilde güncelleyiniz. (Menü oluşturmak için siz manuel giriş yapınız)
# 3.  Yukarıdaki örneği bir sipariş haline getirip, kullanıcının seçtiği yemekler için ödeyecek olduğu hesabı belirten hale getiriniz. (Hazır bir menü sistemi oluşturup hesaplamaları yapınız. Önceki çıktıları kullanabilirsiniz)
# 4. Bir öğrenci tanıma kartı oluşturunuz. öğrenciye adi, soyadı gibi bilgileri sorduktan sonra, derslerini ve derslerine ait notları sorup toplu çıktı veren bir sistem yazınız. (bir nevi cv gibi)
# 5. bir todo list oluşturunuz. oluşturacak olduğunuz yapılacaklar listesinde kullanıcıya görevleri sorunuz, görev listesini yapınız, görevlerin durumunu kontrol ediniz ve tüm görevler tamamlanınca teşekkür ederek programı tamamlayınız.
# 6. yukarıdaki örnek için görev kategorileri tanımlayarak örneği tekrar yapınız.
# 7. yukarıda ki örneği görev kategori ve alt görevler şeklinde güncelleyerek tekrar yapınız.
# 8. böl ve feth et algoritmasını araştırarak, fonksiyon kullanmadan listeler aracılığı ile kullanıcıdan alacak olduğunuz sayılar arasındaki en büyük ve en küçük sayıları hesaplatarak ekrana yazdırınız. (bu biraz uğraştırıcı)
# 9. kullanıcıdan n tane sayı girmesini isteyerek, hangi sayıyı kaçar tane girdiğini kullanıcıya söyleyen programı yazınız.
# 10. kullanıcıya en sevdiği yazarları ve bu yazarlara ait en sevdiği eserleri sorarak, aldığı verileri gruplar halinde listeyen uygulamayı yazınız.
# 11. 2 den 1000'e kadar olan asal sayıları bulan ve yazdıran programı yazınız.

# %% [markdown]
# # Bölüm 6 - Modüller - Hazır Fonksiyonlar

# %% [markdown]
# 1.   bilgisayarın tuttuğu rastgele bir sayıyı bulmaya çalışan bir uygulama yazınız.
# 2.   sizin tuttuğunuz sayıyı bulmaya çalışan bir uygulama yazınız. (yönlendirmeler olmalı daha büyük ve daha küçük şeklinde)
# 3.   bir sayısal loto programı yazınız.
# 4.   Sinüs teoremi kullanarak alan hesabı yapan bir uygulama yazınız.
# 5.   kişiden doğum tarihini isteyerek kaç, kaç hafta ve kaç gündür hayatta olduğunu hesaplayan programı yazınız.
# 6.   bir test sınavı uygulaması yazarak 1 dakikada bir soru soran ve cevap kontrolü yaparak test sonucunu hesaplayan bir uygulama yazınız.
# 7.   sezar şifreleme yöntemini öğrenerek bir metni sezar şifreleme yöntemi ile şifreleyiniz.
# 8.   round kütüphanesini kullanarak çeşitli sayı yuvarlama işlemlerini yapınız.
# 9.   bir alan hesaplayıcı yaparak, çeşitli çok hesapları yapınız. yapacak olduğunuz hesaplamaları bir dosyaya kaydettirerek, sonrasında kullanıcıya dosyadan okutarak istatistiksel olarak bilgilendirme yapınız.
# 10.  kullanıcıdan bir dosya adı isteyerek aradığınız dizinde o dosyanın olup olmadığı bilgisini kullanıcıya veren uygulamayı yazınız.

# %% [markdown]
# # Bölüm 7 - Fonksiyon işlemleri

# %% [markdown]
# 1.   şanslı 7 li programını yazınız. şanslı yedili üç adet rakamın aynı gelmesi ile kazanılan bir şans oyunudur.
# 2.   farklı jeton uygulamaları ile yukarıdaki oyunu tekrar yazınız.
# bir test uygulaması yazınız. yazacak olduğunuz test uygulaması sırası ile kullanıcıdan test sorusu ve cevapları almalı yani bir soru havuzu oluşturmalı, sonrasında kullanıcıya seçim durumuna göre bu havuzdan rastgele sorular sormalı ve cevapları değerlendirerek puan hesaplamalı,
# 3.  yukarıda ki uygulamayı oturum ile yapınız. kullanıcı oturum açar ise soru ekle me menüsü aktif olur iken, misafir kullanıcılar sadece soru cevaplama bölümüne sahip olmalı
# 4.  kullanıcı adları olan bir dosya oluşturunuz, bu kullanıcılara ait şifrelerin olduğu başka bir dosya daha oluşturunuz. kullanıcı oturum sistemi tanımlayarak iki dosyadan okuduğunuz veriler doğrultusunda kullanıcının oturup açmadığını kontrol ediniz.
# 5.  yukarıda eğer kullanıcı oturum açabilir ise oturum açma ve kapama bilgilerini zaman bilgilerini kullanıcı bilgileri ile birlikte farklı bir dosyaya kaydettiriniz.
# 6.  eğer kullanıcı oturum açar ise sonra oturum açma bilgilerini yazdırınız.
# 7.  Fonksiyon kullanarak yarıçapı girilen dairenin alanını hesaplayan Python programı
# 8.   Fonksiyon kullanarak genişliği ve yüksekliği girilen dikdörtgenin alanını hesaplayan Python programı
# 9.    Bir string içerisinde belirlenen bir karakterin olup olmadığını kontrol eden Python programı kodları. Kontrol etme işlemi fonksiyon içinde yapınız.
# 10.   kullanıcının girecek olduğu iki sayı arasındaki asal sayıları bulup yazdıran fonksiyonlu örneği yazınız
# 11.   Liste İçindeki Tekrarlı Değerleri ve kaçar kere tekrar ettiği bilgisini bulan fonksiyonlu örneği yazınız. recursive fonksiyon ve ek olarak dict kullanabilirsiniz.
# 12.   Belirsiz sayıda parametre alan ve bu parametrelerin standart sapmasını veren stdsap() isimli bir fonksiyon yazalım. Standart sapmanın tanımlanabilmesi için fonksiyon en az iki parametre almalı. Bunun dışında parametre sayısında bir kısıtlama olmayacak. Bu şartı sağlamak için fonksiyon arayüzünü stdsap(x1, x2, *y) şeklinde yazmamız gerekir. bir standart sapma hesaplama programı yazınız. *args kullanmanız gerekmektedir.
#
# 13.

# %% [markdown]
# # Bölüm 8 - OOP Nesne Yönelimli Programlama

# %% [markdown]
# # Python Nesne Yönelimli Programlama (OOP) Rehberi
# ## Temel Kavramlar (Soru 1-10)
# ### 1. OOP Nedir?
# **Nesne Yönelimli Programlama (OOP)** nedir ve Python'da neden önemlidir?
# ### 2. Sınıf ve Nesne
# **Sınıf (Class)** ile **Nesne (Object)** arasındaki temel farkı açıklayın ve Python'da bir sınıf ve nesne oluşturma örneği verin.
# ### 3. __init__ metodu
# Python'da `__init__` metodunun amacı nedir ve ne zaman çağrılır?
#
# ### 4. self anahtar kelimesi
# Python sınıflarında `self` anahtar kelimesi neyi temsil eder ve kullanımı neden zorunludur?
#
# ### 5. Örnek ve Sınıf Değişkenleri
# **Örnek Değişkenleri (Instance Variables)** ile **Sınıf Değişkenleri (Class Variables)** arasındaki farkı bir örnekle açıklayın.
#
# ### 6. Metotlar
# Bir sınıf içindeki **metot (method)** nedir? Bir örnek metot tanımlayın.
#
# ### 7. Erişim Belirleyiciler
# Python'da halka açık (public), korumalı (protected) ve özel (private) üyeler nasıl tanımlanır? Gerçekten katı bir erişim kontrolü var mıdır?
#
# ### 8. @property Dekoratorü
# `@property` dekoratörünün kullanım amacı nedir? Bir niteliğe erişimi ve atamayı kontrol etmek için nasıl kullanılır?
#
# ### 9. __str__ ve __repr__
# Python'da `__str__` ve `__repr__` metotlarının farkları nelerdir ve ne zaman hangisini kullanmalıyız?
#
# ### 10. Kalıtımın Temelleri
# **Kalıtım (Inheritance)** nedir? Bir alt sınıfın (subclass) üst sınıftan (superclass) nasıl türetildiğini gösteren basit bir örnek yazın.
#
# ## Dört Temel İlke (Soru 11-18)
#
# ### 11. Kapsülleme (Encapsulation)
# Kapsülleme ilkesini açıklayın. Bu ilke Python'da nasıl uygulanır?
#
# ### 12. Soyutlama (Abstraction)
# Soyutlama nedir ve Python'da soyut sınıflar (abstract classes) ve metotlar (methods) oluşturmak için hangi modül kullanılır? (Örn: abc modülü)
#
# ### 13. Çok Biçimlilik (Polymorphism)
# Çok biçimliliği (Polymorphism) açıklayın. Metot geçersiz kılma (Method Overriding) bunun bir örneği midir?
#
# ### 14. Metot Geçersiz Kılma
# Üst sınıftaki bir metodu alt sınıfta nasıl geçersiz kılarsınız (override)? Bir örnek verin.
#
# ### 15. super() Fonksiyonu
# `super()` fonksiyonunun amacı nedir ve kalıtımda nasıl kullanılır?
#
# ### 16. Çoklu Kalıtım
# Python çoklu kalıtımı (Multiple Inheritance) destekler mi? Destekliyorsa, MRO (Method Resolution Order) nedir ve neden önemlidir?
#
# ### 17. Metot Aşırı Yükleme
# Python metot aşırı yüklemeyi (Method Overloading) destekler mi? Desteklemiyorsa, bunun yerine Python'da aynı işlevi sağlamak için hangi yaklaşımlar kullanılır?
#
# ### 18. Arayüzler (Interfaces)
# Python'da arayüz (interface) kavramı nasıl uygulanır?
#
# ## İleri Düzey Kavramlar ve İlişkiler (Soru 19-25)
#
# ### 19. Kompozisyon ve Kalıtım
# **Kompozisyon (Composition)** ve **Kalıtım (Inheritance)** arasındaki fark nedir? "Is-a" (bir ...dır) ve "Has-a" (bir ...e sahiptir) ilişkilerini açıklayın. Hangi durumda hangisini tercih etmeliyiz?
#
# ### 20. Sınıf Metotları ve Statik Metotlar
# **Sınıf Metotları** (`@classmethod`) ve **Statik Metotlar** (`@staticmethod`) arasındaki farklar nelerdir? Kullanım senaryoları hakkında örnekler verin.
#
# ### 21. Magic/Dunder Metotlar
# "Magic" veya "Dunder" metotlar nedir? Bir sınıfın davranışını değiştirmek için kullanılan en az üç farklı dunder metodunu (örn. `__len__`, `__add__`) açıklayın.
#
# ### 22. Özel İstisnalar
# Kendi özel istisna (exception) sınıfınızı oluşturmak için hangi kalıtım yöntemini kullanmalısınız ve bu neden önemlidir?
#
# ### 23. Mixins
# Mixin (karıştırıcı) sınıflar nedir ve Python'da ne amaçla kullanılırlar?
#
# ### 24. Duck Typing
# Python'da Duck Typing kavramını açıklayın. Bu kavram, OOP ilkeleriyle nasıl ilişkilidir?
#
# ### 25. Tasarım Kalıpları
# OOP prensiplerine dayanan, Python'da sıklıkla kullanılan bir Tasarım Kalıbını (Design Pattern) (örneğin Factory, Singleton, Observer) açıklayın.

# %% [markdown]
# ## 💻 Python OOP Pratik Uygulama Soruları (30 Adet)
#
# Bu pratikler; sınıf oluşturmaktan, kalıtıma, dunder metotlara ve ileri seviye ilişkilere kadar geniş bir yelpazeyi kapsamaktadır.
#
# ### Bölüm 1: Temel Sınıf ve Nesne Oluşturma (1-10)
#
# 1.  **Basit Sınıf:** `Kitap` adında bir sınıf oluşturun. Bu sınıfın herhangi bir özelliği olmasın.
# 2.  **Örnek Oluşturma:** `Kitap` sınıfından `kitap1` ve `kitap2` adında iki farklı nesne oluşturun.
# 3.  **Başlatıcı (`__init__`):** `Araba` adında bir sınıf tanımlayın. Başlatıcı metodunda (`__init__`) `marka`, `model` ve `yil` özelliklerini (instance variables) parametre olarak alıp atayın.
# 4.  **Basit Metot:** `Araba` sınıfına, arabanın tüm özelliklerini (`marka`, `model`, `yil`) ekrana yazdıran `bilgileri_goster` adında bir metot ekleyin.
# 5.  **Sınıf Değişkeni:** `Kedi` sınıfı oluşturun. Bu sınıfa `tur = "Felidae"` adında bir **sınıf değişkeni** ekleyin. Bir `Kedi` nesnesi oluşturun ve sınıf değişkenini ekrana yazdırın.
# 6.  **`self` Kullanımı:** `Dikdortgen` adında bir sınıf oluşturun. `__init__` metodunda `genislik` ve `yukseklik` özelliklerini tanımlayın. `alan_hesapla` adında, alan değerini döndüren bir metot yazın.
# 7.  **Değer Atama Metodu:** `Hesap` adında bir sınıf oluşturun. `bakiye` özelliği olsun. `para_yatir` adında, bakiyeyi artıran bir metot yazın.
# 8.  **Değer Okuma Metodu:** `Hesap` sınıfına, mevcut bakiyeyi döndüren `bakiyeyi_goster` adında bir metot ekleyin.
# 9.  **Özel (Private) Nitelik Simülasyonu:** `Personel` sınıfı oluşturun. Maaşı temsil eden `_maas` özelliğini oluşturun (tek alt çizgi ile). Bu özelliğe dışarıdan erişimi sağlayan ve atamayı kontrol eden (örn: maaşın negatif olmamasını sağlayan) `maas_ayarla` ve `maas_oku` metotlarını ekleyin.
# 10. **`@property` Kullanımı:** `Personel` sınıfındaki `_maas` özelliğine erişmek ve değiştirmek için önceki sorudaki metotlar yerine `@property` ve `@maas.setter` dekoratörlerini kullanın.
#
# ### Bölüm 2: Kalıtım ve Polimorfizm (11-20)
#
# 11. **Basit Kalıtım:** `Hayvan` adında bir üst sınıf oluşturun ve `ses_cikar` adında bir metot ekleyin. `Kopek` adında, `Hayvan` sınıfından türeyen bir alt sınıf oluşturun.
# 12. **Metot Geçersiz Kılma (Overriding):** `Kopek` sınıfında `ses_cikar` metodunu geçersiz kılın (override) ve "Hav hav!" yazdırsın.
# 13. **`super()` Kullanımı:** `Mudur` adında, `Personel` (9. sorudaki sınıfı kullanabilirsiniz) sınıfından türeyen bir sınıf oluşturun. `__init__` metodunda `Personel`'in başlatıcısını `super()` kullanarak çağırın ve ek olarak `departman` özelliğini tanımlayın.
# 14. **Çoklu Kalıtım:** `Ucan` ve `Yuzen` adında iki basit sınıf (Mixin) oluşturun. Her birinde ilgili metotlar (örn: `uc()`, `yuz()`) olsun. `Ordek` adında, her iki sınıftan da miras alan bir sınıf oluşturun.
# 15. **MRO (Metot Çözünürlük Sırası):** Önceki sorudaki `Ordek` sınıfının MRO'sunu (Metot Çözünürlük Sırasını) gösteren kodu yazın (`Ordek.__mro__`).
# 16. **Polimorfizm Uygulaması:** `Kare` ve `Ucgen` adında iki farklı sınıf oluşturun. Her ikisinde de `alan_hesapla()` adında bir metot olsun, ancak farklı formüller kullansınlar. Bu iki nesneyi içeren bir liste üzerinde döngü yapın ve her nesnenin `alan_hesapla()` metodunu çağırın.
# 17. **Soyut Sınıf (Abstraction):** `abc` modülünü kullanarak `Sekil` adında bir soyut sınıf (`ABC`) oluşturun ve `alan_hesapla` adında soyut bir metot (`@abstractmethod`) tanımlayın.
# 18. **Soyut Metot Uygulaması:** `Kare` sınıfını `Sekil` sınıfından türetin ve `alan_hesapla` metodunu zorunlu olarak uygulayın.
# 19. **Kalıtım Zinciri:** `Varlik` adında bir üst sınıf, ondan türeyen `CanliVarlik`, ondan türeyen `Insan` ve ondan türeyen `Ogrenci` sınıflarını oluşturarak bir kalıtım zinciri kurun.
# 20. **Özellik Gizleme:** `Personel` sınıfında (9. sorudaki), maaşı `_maas` yerine **çift alt çizgi** ile `__maas` yaparak gerçek özel nitelik (name mangling) olarak tanımlayın ve dışarıdan doğrudan erişmeye çalışın. Ne olduğunu gözlemleyin.
#
# ### Bölüm 3: İleri Kavramlar ve İlişkiler (21-30)
#
# 21. **Kompozisyon (Has-a İlişkisi):** `Adres` adında bir sınıf oluşturun. `Musteri` adında bir sınıf daha oluşturun ve `Musteri` sınıfının `__init__` metodunda `Adres` sınıfından bir nesneyi özellik olarak tanımlayın. (Bir Müşterinin bir Adresi vardır).
# 22. **Liste Desteği (Dunder):** `Liste` adında bir sınıf oluşturun. `__len__` dunder metodunu uygulayarak bu sınıfın nesnelerinin `len()` fonksiyonu ile kullanılabilmesini sağlayın.
# 23. **Toplama Desteği (Dunder):** `Vektor` adında bir sınıf oluşturun. `__init__` metodu `x` ve `y` bileşenlerini alsın. İki `Vektor` nesnesini toplamak için `__add__` dunder metodunu uygulayın.
# 24. **Sınıf Metodu (`@classmethod`):** `Tarih` adında bir sınıf oluşturun (`yil`, `ay`, `gun` özellikleri olsun). Yılın gün sayısını (örn. 365) parametre olarak alıp o güne karşılık gelen `Tarih` nesnesini döndüren bir `@classmethod` oluşturun.
# 25. **Statik Metot (`@staticmethod`):** `Matematik` adında bir sınıf oluşturun ve bu sınıfa, iki sayının EKOK'unu (En Küçük Ortak Kat) hesaplayan, ne sınıfa ne de örneğe ihtiyaç duyan bir `@staticmethod` ekleyin.
# 26. **Tekil Desen (Singleton):** Bir uygulamanın sadece tek bir örneğinin (instance) olmasına izin veren `Ayarlar` adında bir sınıf (Singleton deseni) oluşturmaya çalışın. (Örn: `__new__` metodunu kullanın).
# 27. **İterasyon (Dunder):** Bir listenin elemanlarını tutan `OzelListe` adında bir sınıf oluşturun ve `__iter__` ile `__next__` metotlarını uygulayarak bu nesnenin bir döngüde (`for item in liste:`) kullanılabilmesini sağlayın.
# 28. **Koleksiyon Sınıfı:** `Ogrenci` adında bir sınıf oluşturun. Ardından, birden çok `Ogrenci` nesnesini içinde tutan `Sinif` adında başka bir sınıf oluşturun ve bu öğrencileri bir liste içinde saklayın.
# 29. **Nesne Temsili (`__str__`):** 3. sorudaki `Araba` sınıfına, `print(araba_nesnesi)` çağrıldığında okunabilir bir çıktı (örn: "Marka: Ford, Model: Fiesta, Yıl: 2020") verecek şekilde `__str__` dunder metodunu uygulayın.
# 30. **Hata Yönetimi (Özel İstisna):** Banka hesabından para çekme işlemi sırasında, bakiyenin yetersiz olduğu durumlarda fırlatılmak üzere `YetersizBakiyeHatasi` adında özel bir istisna sınıfı (`Exception` sınıfından türeyerek) oluşturun.

# %% [markdown]
# # Bölüm 9 - Veri Tabanı İşlemleri

# %% [markdown]
# ## 💾 SQLite ve SQLAlchemy Soruları
#
# Bu sorular, hem SQLite yerel veritabanı işlemlerini hem de SQLAlchemy ORM (Nesne İlişkisel Eşleyici) kullanımını kapsar.
#
# ### Bölüm 1: SQLite (Yerel Veritabanı İşlemleri) Soruları (1-10)
#
# Bu sorular, Python'ın yerleşik `sqlite3` kütüphanesiyle doğrudan SQL komutları yazma pratiği üzerine odaklanır.
#
# 1.  **Bağlantı Kurma:** Python'da `sqlite3` kütüphanesini kullanarak `ogrenci_db.sqlite` adında yeni bir veritabanına nasıl bağlantı kurulur? Bağlantı nesnesini ve imleç (cursor) nesnesini oluşturun.
# 2.  **Tablo Oluşturma:** Veritabanında `Ogrenciler` adında bir tablo oluşturmak için gerekli SQL komutunu yazın. Tablonun `id` (PRIMARY KEY, INTEGER), `ad` (TEXT), `soyad` (TEXT) ve `sinif` (INTEGER) sütunları olmalıdır.
# 3.  **Tekil Veri Ekleme:** `Ogrenciler` tablosuna `('Ahmet', 'Yılmaz', 9)` verisini eklemek için kullanılan SQL sorgusunu hazırlayın ve `execute()` metodu ile nasıl çalıştırıldığını gösterin.
# 4.  **Çoklu Veri Ekleme:** Aşağıdaki üç öğrenci verisini tek bir işlemde eklemek için `executemany()` metodunu nasıl kullanırsınız?
#     `[('Ayşe', 'Kara', 10), ('Mehmet', 'Demir', 9), ('Elif', 'Can', 11)]`
# 5.  **Veri Sorgulama (SELECT):** `Ogrenciler` tablosundaki tüm öğrencilerin ad ve soyadlarını çekmek için gerekli SQL sorgusunu yazın ve sonuçları `fetchall()` ile nasıl aldığınızı belirtin.
# 6.  **Koşullu Sorgulama (WHERE):** Sadece 9. sınıftaki öğrencileri sorgulamak için gerekli SQL sorgusunu yazın.
# 7.  **Veri Güncelleme (UPDATE):** Adı 'Ahmet' olan öğrencinin sınıfını 10 olarak güncellemek için gerekli SQL ve Python kodunu yazın.
# 8.  **Veri Silme (DELETE):** Adı 'Elif' olan öğrenciyi tablodan silmek için gerekli SQL ve Python kodunu yazın.
# 9.  **İşlem Yönetimi:** Bir veritabanı değişikliğinin (INSERT, UPDATE veya DELETE) kalıcı olarak kaydedilmesi (`commit`) ve bir hatada değişikliklerin geri alınması (`rollback`) hangi Python metotları ile yapılır?
# 10. **Kaynak Yönetimi:** Veritabanı ile işiniz bittiğinde bağlantıyı kapatmak için hangi metot kullanılır ve bu neden önemlidir?
#
# ### Bölüm 2: SQLAlchemy ORM (Nesne İlişkisel Eşleyici) Soruları (11-20)
#
# Bu sorular, SQLAlchemy'nin Nesne İlişkisel Eşleyici (ORM) kısmına ve Python sınıflarıyla veritabanı etkileşimine odaklanır.
#
# 11. **ORM Nedir?:** ORM (Object Relational Mapper) nedir? SQLAlchemy'nin ORM kullanmanın temel avantajları nelerdir?
# 12. **Gerekli İçe Aktarmalar:** SQLAlchemy ORM kullanılarak bir veritabanı tablosu tanımlamak için gerekli temel içe aktarmaları (`import`) listeleyin.
# 13. **Engine ve Base:** `sqlite:///okul.db` veritabanına bağlanmak için `create_engine` fonksiyonunu nasıl kullanırsınız? Ayrıca, ORM sınıflarınız için temel sınıfı (`Base`) nasıl tanımlarsınız?
# 14. **ORM Sınıfı Tanımlama:** `Ders` adında bir Python sınıfı tanımlayın. Bu sınıfın veritabanındaki `dersler` tablosunu temsil etmesini sağlayın. Özellikler: `id` (Primary Key), `ad` (String), `kredi` (Integer).
# 15. **Tablo Oluşturma:** Tanımlanan ORM sınıflarının, veritabanında ilgili tabloları oluşturması için hangi `Base` metodunu kullanırsınız?
# 16. **Session (Oturum) Kavramı:** SQLAlchemy ORM'de **Session** (Oturum) neyi temsil eder ve neden önemlidir? Oturum nesnesini nasıl oluşturursunuz?
# 17. **Veri Ekleme (ADD):** `Ders` sınıfından bir nesne (`Python Programlama`, 5 kredi) oluşturun ve bunu oturuma ekleyip veritabanına kaydetmek için hangi adımları takip etmelisiniz?
# 18. **Tümünü Sorgulama (Query):** Oturum üzerinden `Ders` tablosundaki **tüm** dersleri nasıl sorgularsınız? Sorgu sonuçlarını bir liste olarak nasıl alırsınız?
# 19. **Filtreleyerek Sorgulama (Filter):** Kredisi 5'ten büyük olan dersleri sorgulamak için `filter()` metodunu nasıl kullanırsınız?
# 20. **Veri Güncelleme (Update):** Adı 'Python Programlama' olan dersi bulup kredisini 6 olarak güncellemek için gereken kod adımlarını yazın.
#
# ### Bölüm 3: İleri Düzey İlişkiler ve Kavramlar (21-25)
#
# 21. **Bire-Çok İlişkisi (One-to-Many):** `Ogretmen` ve `Ders` sınıfları arasında (Bir Öğretmen birden çok Ders verebilir) bire-çok ilişkisini kurmak için hangi SQLAlchemy fonksiyonlarını (`relationship` ve `ForeignKey`) ve nasıl kullanırsınız?
# 22. **Lazy Loading:** SQLAlchemy'de **Lazy Loading** nedir ve bu, ilişkili verilerin (örneğin bir öğretmenin derslerinin) ne zaman veritabanından yüklendiğini nasıl etkiler?
# 23. **Toplu Sorgulama (Bulk Operations):** Birçok nesneyi tek bir oturumda verimli bir şekilde veritabanına kaydetmek için (tek tek `add()` yerine) hangi metotları kullanabilirsiniz?
# 24. **SQL Injection Koruması:** SQLAlchemy ORM, veritabanı işlemlerinde SQL Injection saldırılarına karşı nasıl koruma sağlar?
# 25. **Commit ve Rollback (ORM):** SQLAlchemy ORM'de oturumdaki (session) değişiklikleri veritabanına kaydetmek ve bir hata durumunda bu değişiklikleri geri almak için kullanılan temel metotlar nelerdir?

# %% [markdown]
# ## 🐍 ↔️ 💾 Bölüm  Python OOP & SQLAlchemy ORM Kod Pratiği (15 Soru)
#
# Aşağıdaki soruları çözerken, her senaryo için uygun Python sınıflarını tanımlamalı ve SQLAlchemy ORM kullanarak veritabanı işlemlerini gerçekleştirmelisiniz.
#
# ### Bölüm 1: Temel Sınıf ve CRUD Pratikleri
#
# **Soru 1: Tekil Varlık Tanımlama ve Ekleme (OOP & ORM)**
# * `Urun` adında bir Python sınıfı tanımlayın. Bu sınıf, veritabanında `urunler` tablosunu temsil etmelidir.
# * Özellikleri: `id` (Primary Key, Integer), `ad` (String), `fiyat` (Float).
# * Bu sınıftan bir ürün nesnesi (`Laptop`, 12500.00 TL) oluşturun ve ORM oturumu (Session) üzerinden veritabanına ekleyip kaydedin (`commit`).
#
# **Soru 2: Veri Güncelleme**
# * Veritabanındaki ID'si 1 olan `Urun` nesnesini sorgulayın (`session.get()` veya `session.query().filter()`).
# * Bu nesnenin `fiyat` özelliğini 13500.00 TL olarak güncelleyin ve değişikliği veritabanına kaydedin.
#
# **Soru 3: Listeleme ve Nesne Temsili**
# * `Urun` sınıfına, nesne yazdırıldığında ürün adını ve fiyatını döndüren bir `__repr__` dunder metodu ekleyin (Örn: `Urun(ad='Laptop', fiyat=13500.0)`).
# * Veritabanındaki **tüm** ürünleri sorgulayın ve bir döngü içinde ekrana yazdırarak `__repr__` çıktısını gözlemleyin.
#
# **Soru 4: Koşullu Sorgulama (Filtreleme)**
# * Fiyatı **10000.00 TL'den büyük** olan tüm `Urun` nesnelerini sorgulamak için `session.query().filter()` metodunu kullanın ve sonuçları ekrana yazdırın.
#
# **Soru 5: Silme İşlemi**
# * Adı 'Laptop' olan ürünü sorgulayın.
# * Bu nesneyi ORM oturumu üzerinden silmek için gerekli metodu çağırın (`session.delete()`) ve işlemi kaydedin.
#
# ### Bölüm 2: Kalıtım ve Basit İlişkiler Pratikleri
#
# **Soru 6: Kalıtım Modeli (Single Table Inheritance)**
# * `Personel` adında bir üst sınıf tanımlayın (`id`, `ad`, `maas`).
# * Bu sınıftan türeyen `Yonetici` ve `Calisan` adında iki alt sınıfı, SQLAlchemy'nin **Single Table Inheritance** özelliğini kullanarak tek bir veritabanı tablosunda modelleyin (`polymorphic_identity` ve `__mapper_args__` kullanın).
# * Her iki tipten birer nesne oluşturun ve kaydedin.
#
# **Soru 7: Bire-Çok İlişkisi (Yazar-Kitap)**
# * `Yazar` sınıfı ve `Kitap` sınıfını tanımlayın.
# * `Kitap` sınıfına, yazarın ID'sini tutan bir `yazar_id` **ForeignKey** ekleyin.
# * `Yazar` sınıfına ise, ilişkili tüm `Kitap` nesnelerine erişimi sağlayan bir **`relationship`** özelliği tanımlayın.
#
# **Soru 8: İlişkisel Veri Ekleme ve Sorgulama**
# * Yeni bir `Yazar` nesnesi (`Yazar A`) oluşturun.
# * Bu yazar için iki farklı `Kitap` nesnesi oluşturun.
# * Bu kitapları doğrudan yazar nesnesinin ilişkili niteliğine atayarak (örn: `yazar_a.kitaplar = [kitap1, kitap2]`) tek bir `session.add(yazar_a)` ile tümünü veritabanına kaydedin.
#
# **Soru 9: Ters İlişkiye Erişim**
# * Önceki soruda kaydettiğiniz kitaplardan birini sorgulayın.
# * Bu `Kitap` nesnesinin üzerinden, ilişkili `Yazar` nesnesine (`kitap.yazar`) erişerek yazarın adını ekrana yazdırın.
#
# **Soru 10: İlişkili Veri Güncelleme**
# * Mevcut bir `Yazar` nesnesini sorgulayın.
# * Yazarın `kitaplar` listesine, yeni oluşturduğunuz üçüncü bir `Kitap` nesnesini ekleyin ve `session.commit()` yaparak sadece yeni kitabın veritabanına eklendiğini doğrulayın.
#
# ### Bölüm 3: İleri Düzey İlişkiler ve Kapsülleme Pratikleri
#
# **Soru 11: Çoktan Çoğa İlişkisi (Öğrenci-Ders)**
# * `Ogrenci` ve `Ders` adında iki temel sınıf tanımlayın.
# * Bu iki sınıf arasında bir **Çoktan Çoğa** ilişkisi kurmak için, sadece `ogrenci_id` ve `ders_id` sütunlarını içeren bir ilişki tablosu (`ogrenci_ders_iliskisi`) tanımlayın.
# * İki öğrenci ve iki ders ekleyip aralarındaki ilişkiyi kurun.
#
# **Soru 12: İlişki Tablosuna Payload Ekleme**
# * Önceki sorudaki ilişki tablosunu (`OgrenciDersKaydi`) ayrı bir ORM sınıfı olarak tanımlayın.
# * Bu sınıfa, öğrencinin dersten aldığı notu (`notu`, Integer) tutan bir sütun ekleyin.
# * Bir öğrenciyi bir derse eklerken, aynı anda aldığı notu da bu ilişki sınıfı üzerinden kaydedin.
#
# **Soru 13: Kompozisyon Modeli (Has-a İlişkisi)**
# * `Adres` sınıfını (`cadde`, `sehir`) ve `Musteri` sınıfını (`ad`) ayrı ayrı tanımlayın.
# * `Musteri` sınıfında, `Adres` sınıfına Bire-Çok (One-to-Many) ilişkisini kurun ve **Kompozisyon** ilişkisini modellemek için ilişkiyi kurun (Bir Müşteri Bir Adrese Sahiptir).
# * Bir Müşteri oluşturun ve adresini aynı anda kaydedin.
#
# **Soru 14: OOP ile Dinamik Sorgulama**
# * `Raporlama` adında bir Python sınıfı oluşturun (ORM sınıfı değil).
# * Bu sınıfa, `fiyat_filtresi_uygula(session, sinif, esik_fiyat)` adında bir metot ekleyin. Bu metot, kendisine verilen ORM sınıfını (`sinif`) ve fiyat eşiğini (`esik_fiyat`) kullanarak **dinamik** bir sorgu çalıştırmalıdır (Örn: `session.query(sinif).filter(sinif.fiyat > esik_fiyat)`).
# * Bu metodu `Urun` sınıfı ile çağırıp test edin.
#
# **Soru 15: Oturum Yönetimi Kapsüllemesi**
# * `VeritabaniServisi` adında bir sınıf oluşturun.
# * Bu sınıfın `kaydet(nesne)` adında bir metodu olsun. Bu metot, içerde bir oturum açmalı, nesneyi eklemeli (`add`), kaydetmeli (`commit`) ve oturumu kapatmalıdır.
# * **Bonus:** Oturumu açma, commit etme ve kapatma işlemlerini yönetmek için Python'ın `contextlib` modülünü veya özel bir `__enter__` / `__exit__` metodu kullanarak bir **Context Manager** (`session_scope`) oluşturun ve `kaydet` metodunu bununla kapsülleyin.

# %% [markdown]
# ## 🌐 Web Otomasyonu ve API Kullanımı Soruları (45 Adet)
#
# ### Oturum 1: `requests` ile API Kullanımı, JSON Verisi, Hava Durumu Uygulaması (15 Soru)
#
# #### Temel Kavramlar ve `requests`
#
# 1.  **API Nedir?** Açılımı nedir ve bir web uygulamasında temel görevi nedir?
# 2.  **RESTful API:** RESTful mimarinin temel prensipleri nelerdir?
# 3.  **HTTP Metotları:** En sık kullanılan 4 temel HTTP metodu (`GET`, `POST`, `PUT`, `DELETE`) ve kullanım amaçlarını açıklayın.
# 4.  **`requests` Kütüphanesi:** Python'da `requests` kütüphanesini kullanmanın temel amacı nedir?
# 5.  **Status Kodları:** Bir `requests.get()` çağrısından dönen 200, 404, 500 gibi HTTP durum kodları ne anlama gelir?
#
# #### JSON Verisi ve İşleme
#
# 6.  **JSON Nedir?** JSON (JavaScript Object Notation) nedir ve veriyi hangi formatta saklar? Python'da JSON'a karşılık gelen veri yapıları nelerdir?
# 7.  **JSON Serileştirme/Seri Olmayan:** Serileştirme (Serialization) ve Seri Olmayan hale getirme (Deserialization) terimlerini açıklayın. Python'da hangi fonksiyonlar (`json` modülü) bu işi yapar?
# 8.  **`response.json()`:** Bir `requests` cevabından JSON verisini doğrudan Python sözlüğü (dictionary) olarak almak için hangi metot kullanılır?
# 9.  **Try-Except Kullanımı:** API çağrısı sırasında bağlantı veya JSON çözümleme hatası almamak için ne tür bir hata yönetimi yapmalısınız? (Örn: `requests.exceptions.RequestException` veya `json.JSONDecodeError`).
# 10. **Başlıklar (Headers):** Bir API çağrısına özel bilgiler (örn: kimlik doğrulama token'ı, veri tipi) eklemek için istek başlıkları (`headers`) nasıl kullanılır?
#
# #### Pratik Uygulama: Hava Durumu API'si
#
# 11. **API Anahtarı:** Bir Hava Durumu API'sini kullanmak için genellikle gereken **API Anahtarı** ne işe yarar ve istekte nasıl gönderilir (genellikle URL parametresi mi, başlık mı?)?
# 12. **Sorgu Parametreleri:** İstanbul için hava durumu verisi çekmek üzere bir `GET` isteği hazırlarken, şehir adı (örn: `q=Istanbul`) gibi sorgu parametreleri (`params`) `requests` kütüphanesinde nasıl tanımlanır?
# 13. **Veri Çözümleme:** API'den dönen hava durumu JSON verisinde, sıcaklık bilgisinin derin bir sözlük yapısında olduğunu varsayarak, bu bilgiye Python sözlük erişimiyle nasıl ulaşılır?
# 14. **Uygulama Fonksiyonu:** Belirli bir şehri parametre olarak alan ve hava durumu bilgisini (sıcaklık, nem) döndüren bir Python fonksiyonu (`hava_durumu_cek(sehir)`) yazın.
# 15. **Hata Kontrolü:** Fonksiyonunuzda, API'den 404 (Şehir Bulunamadı) yanıtı geldiğinde kullanıcıya anlaşılır bir hata mesajı döndürmek için ne tür bir kontrol yapmalısınız?
#
# ---
#
# ### Oturum 2: `BeautifulSoup` ile Web Scraping, CSS Seçiciler, Haber Başlıkları Çekme (15 Soru)
#
# #### Web Scraping ve `BeautifulSoup` Temelleri
#
# 16. **Web Scraping Nedir?** Web kazıma (scraping) nedir ve temel amacı nedir?
# 17. **Yasal/Etik Sınırlamalar:** Web kazıma yapmadan önce kontrol edilmesi gereken en önemli etik ve yasal dosya/sayfa nedir?
# 18. **`BeautifulSoup`:** `BeautifulSoup` kütüphanesinin temel görevi nedir? Hangi kütüphane (örneğin `requests`) ile birlikte kullanılır?
# 19. **HTML Ayrıştırma (Parser):** `BeautifulSoup` nesnesini oluştururken neden bir ayrıştırıcı (parser) belirtilir (örn: `'html.parser'`)?
# 20. **Tag'lara Erişim:** Bir HTML belgesindeki ilk `<h1>` etiketine erişmek için kullanılan `BeautifulSoup` metodu nedir?
#
# #### Seçiciler ve Filtreleme
#
# 21. **CSS Seçici:** CSS seçici (selector) nedir? Bir örnek verin (örn: `div.content > p`).
# 22. **`find()` ve `find_all()`:** Bu iki metot arasındaki temel fark nedir? Hangi durumda hangisini kullanmayı tercih edersiniz?
# 23. **Sınıfa Göre Seçme:** Sınıfı `haber-baslik` olan tüm `div` etiketlerini bulmak için `find_all()` metodunu nasıl kullanırsınız?
# 24. **ID'ye Göre Seçme:** ID'si `ana_icerik` olan tek bir `div` etiketini bulmak için `find()` metodunu nasıl kullanırsınız?
# 25. **Nitelik (Attribute) Filtreleme:** `href` niteliği `/kategori/spor` ile başlayan tüm `a` etiketlerini filtrelemek için nasıl bir yöntem kullanabilirsiniz?
# 26. **Metin Çekme:** Bulduğunuz bir HTML etiketinin (tag) içindeki metin içeriğini temiz bir şekilde almak için hangi metot/nitelik kullanılır?
#
# #### Pratik Uygulama: Haber Başlıkları
#
# 27. **İç İçe Elementler:** Haber başlıklarının bir `div` içindeki `h2` etiketlerinde olduğunu varsayarak, önce ana `div`'i bulup sonra içindeki `h2`'lere erişmek için gereken kod yapısını özetleyin.
# 28. **Tekrarlayan Çekim:** Bir haber sitesindeki 10 farklı haber başlığını içeren bir listeyi nasıl oluşturursunuz? (Genellikle bir döngü ve `find_all()` kullanılır).
# 29. **URL Çekme:** Bir haber başlığı etiketinin hemen yanındaki `a` etiketinden, haberin tam URL'sini (`href` niteliği) nasıl çekersiniz?
# 30. **Veri Yapısı:** Çektiğiniz haber başlıklarını ve URL'lerini, her birinin bir sözlük olduğu bir listeye (List of Dictionaries) nasıl dönüştürürsünüz?
#
# ---
#
# ### Oturum 3: `Selenium` ile Tarayıcı Otomasyonu (15 Soru)
#
# #### Selenium ve Kurulum
#
# 31. **Selenium Nedir?** Selenium'un temel amacı ve `requests`/`BeautifulSoup`'tan temel farkı nedir? (Örn: JavaScript çalıştırma yeteneği).
# 32. **Web Sürücüsü (WebDriver):** WebDriver ne işe yarar? Chrome için gerekli olan sürücüyü nasıl kurar ve Python kodunda nasıl başlatırsınız?
# 33. **Gecikme Sorunu:** Web otomasyonunda bekleme (waiting) neden önemlidir? Hangi iki temel bekleme türü (Implicit vs. Explicit Wait) kullanılır?
# 34. **Görünmez Tarayıcı:** Tarayıcıyı kullanıcı arayüzü olmadan çalıştırmak için kullanılan mod (headless mode) nedir ve nasıl etkinleştirilir?
#
# #### Element Bulma ve Etkileşim
#
# 35. **Element Bulma Stratejileri:** Bir web elementini bulmak için kullanılan en yaygın 3 yöntem (örn: ID, Class Name, XPath/CSS Selector) nedir?
# 36. **Form Doldurma:** Bir metin giriş alanına veri (örn: kullanıcı adı) göndermek için kullanılan `WebElement` metodu nedir?
# 37. **Tıklama:** Bir butona veya bağlantıya programatik olarak tıklamak için kullanılan metot nedir?
# 38. **XPath ve CSS Selector:** Bir elementi bulmak için XPath veya CSS Selector kullanmak arasındaki temel farklar nelerdir?
# 39. **Dropdown Seçimi:** Bir HTML `<select>` (açılır liste) etiketindeki belirli bir seçeneği seçmek için `Selenium`'da kullanılan özel sınıf/metotlar nelerdir?
#
# #### Pratik Uygulama: Form Otomasyonu
#
# 40. **Başlangıç Kodu:** `Selenium` ile bir web sitesini açmak için gereken temel Python kod yapısını yazın.
# 41. **Login Otomasyonu:** Bir oturum açma sayfasında:
#     a) Kullanıcı adı giriş alanını ID'sine göre bulun.
#     b) Şifre giriş alanını CSS Selector'e göre bulun.
#     c) Her iki alana da sahte veri gönderin.
# 42. **Tıklama ve Gezinme:** Giriş butonuna tıkladıktan sonra, yeni sayfadaki bir başlığın metnini nasıl çekersiniz?
# 43. **Tarayıcı İşlemleri:** Sayfayı aşağı kaydırmak, tarayıcı penceresinin boyutunu ayarlamak veya geri/ileri gitmek için kullanılan `WebDriver` metotlarından birini açıklayın.
# 44. **Hata Yönetimi (Element Bulunamaması):** Bir elementi bulmaya çalışırken (örn: `find_element()`), element mevcut değilse fırlatılan hata türü nedir? Bu hatayı nasıl yakalarsınız?
# 45. **Oturumu Kapatma:** Otomasyon işi bittiğinde tarayıcı penceresini kapatmak ve `WebDriver` oturumunu sonlandırmak için kullanılan metotlar nelerdir?

# %% [markdown]
# ## 💻 Web Otomasyonu ve API Kullanımı Pratik Soruları (45 Adet)
#
# Bu sorular, her bir oturum konusunu kapsayan ve doğrudan kod yazmanızı gerektiren pratik uygulamalardır.
#
# ### Oturum 1 Pratikleri: `requests` ve API (15 Soru)
#
# **Amaç:** API'den veri çekmek, JSON'u işlemek ve temel hata yönetimi yapmak.
#
# 1.  **Temel GET İsteği:** `requests` kütüphanesini içe aktarın ve `https://jsonplaceholder.typicode.com/posts/1` adresine bir `GET` isteği yapın. Yanıtın durum kodunu (`status_code`) ekrana yazdırın.
# 2.  **JSON Verisi Alma:** Önceki isteğin JSON yanıtını alın ve bir Python sözlüğüne dönüştürün. Sözlüğün `title` anahtarındaki değeri ekrana yazdırın.
# 3.  **Hava Durumu API Simülasyonu:** Aşağıdaki URL ve parametreleri kullanarak bir `GET` isteği yapın ve isteğin URL'sinin doğru oluşup oluşmadığını kontrol edin:
#     * URL: `https://api.exampleweather.com/v1/current`
#     * Parametreler: `{'city': 'Ankara', 'units': 'metric'}`
# 4.  **Hava Durumu Verisini Çözümleme:** Simüle edilmiş API yanıtının aşağıdaki JSON yapısında olduğunu varsayarak, `'current_temp'` değerini çekin:
#     ```json
#     {"data": {"city": "Ankara", "weather": {"current_temp": 15.2, "humidity": 70}}}
#     ```
# 5.  **POST İsteği (Yeni Kayıt):** `https://jsonplaceholder.typicode.com/posts` adresine aşağıdaki veriyi içeren bir `POST` isteği yapın. Yanıt olarak dönen nesnenin `id` değerini yazdırın:
#     ```python
#     payload = {'title': 'deneme baslik', 'body': 'deneme icerik', 'userId': 1}
#     ```
# 6.  **Hata Kontrolü (`.raise_for_status`):** `https://httpbin.org/status/404` adresine bir istek yapın ve `response.raise_for_status()` metodunu kullanarak bir HTTP hatası fırlatılıp fırlatılmadığını gözlemleyin.
# 7.  **Başlık Ekleme (Headers):** Bir API'ye gönderilecek bir `requests` isteğine `{'Authorization': 'Bearer_token_xyz'}` başlığını nasıl eklersiniz? Kodu yazın.
# 8.  **Fonksiyonel Kapsülleme:** Şehir adını parametre olarak alan ve yukarıdaki simüle edilmiş hava durumu API'sine istek yapıp sıcaklık değerini döndüren bir fonksiyon yazın.
# 9.  **Try/Except ile Hata Yönetimi:** Önceki fonksiyonu, bir hata oluştuğunda (örn: bağlantı hatası) `'API'ye ulaşılamadı'` mesajını döndürecek şekilde `try-except` bloğu içine alın.
# 10. **Listenin İşlenmesi:** `https://jsonplaceholder.typicode.com/users` adresinden tüm kullanıcıları çekin. Dönüş listesi üzerinde döngü yaparak her kullanıcının sadece adını (`name`) ve e-posta adresini (`email`) ekrana yazdırın.
# 11. **URL Kodlama:** Sorgu parametrelerinde Türkçe karakter (Örn: `q=İzmir`) kullanıldığında `requests` kütüphanesinin URL kodlamayı (encoding) otomatik olarak nasıl yaptığını gösteren bir örnek yazın.
# 12. **Özel Timeout:** Bir isteğin maksimum 5 saniye içinde tamamlanmasını sağlamak için `requests.get()` metoduna hangi parametreyi eklemelisiniz?
# 13. **Veri Filtreleme:** `https://jsonplaceholder.typicode.com/todos` adresinden tüm yapılacaklar listesini çekin ve sadece `completed: True` olan görevlerin başlıklarını (`title`) bir Python listesine toplayın.
# 14. **JSON Verisinin Dosyaya Yazılması:** Çektiğiniz bir JSON verisini, standart `json` kütüphanesini kullanarak, okunabilir (indent: 4) formatta bir dosyaya (`veri.json`) yazın.
# 15. **DELETE İsteği:** `https://jsonplaceholder.typicode.com/posts/1` adresindeki gönderiyi silmek için gereken `requests` metodunu çağırın.
#
# ---
#
# ### Oturum 2 Pratikleri: `BeautifulSoup` ve Web Scraping (15 Soru)
#
# **Amaç:** HTML'i ayrıştırmak, CSS ve nitelik seçicileri kullanarak veri çekmek.
#
# 16. **Hazırlık:** Bir HTML içeriğini simüle eden çok satırlı bir string (`html_doc`) tanımlayın ve `BeautifulSoup` nesnesi oluşturun.
#     ```html
#     "<html><body><h1 id='ana-baslik'>Web Scraping</h1><p class='ozet'>...</p></body></html>"
#     ```
# 17. **Basit Tag Bulma:** Simüle edilen HTML belgesindeki ilk `h1` etiketini bulun ve etiket adını ekrana yazdırın.
# 18. **ID Seçici:** ID'si `ana-baslik` olan etiketi bulun ve içindeki metni (`.text` veya `get_text()`) ekrana yazdırın.
# 19. **Sınıf Seçici (`find()`):** Sınıfı `ozet` olan `p` etiketini bulun ve içindeki metni yazdırın.
# 20. **Tümünü Bulma (`find_all`):** Aşağıdaki HTML yapısında sınıfı `haber-baslik` olan **tüm** `a` etiketlerini bir liste olarak çekin.
#     ```html
#     <a class="haber-baslik" href="/haber/1">...</a>
#     <a class="haber-baslik" href="/haber/2">...</a>
#     ```
# 21. **Nitelik Değeri Çekme:** Önceki soruda bulduğunuz `haber-baslik` etiketlerinden ilkinin `href` nitelik değerini (`['href']`) çekin.
# 22. **CSS Seçici ile Seçim:** `select_one()` metodunu kullanarak ID'si `ana-baslik` olan etiketi bulun ve metnini yazdırın.
# 23. **İç İçe Seçim:** Aşağıdaki yapıdan, `ana-icerik` div'i altındaki **tüm** `li` etiketlerini çekmek için CSS seçiciyi kullanın.
#     ```html
#     <div id="ana-icerik"><ul><li>Madde 1</li><li>Madde 2</li></ul></div>
#     ```
# 24. **Filtreleme Fonksiyonu:** `find_all()` metoduna bir Python fonksiyonu (lambda) vererek, **sınıfı hem 'kirmizi' hem de 'buyuk' olan** tüm etiketleri filtreleyin.
# 25. **Tüm Metni Çekme:** Aşağıdaki yapıda, `div` içindeki **tüm metni** (alt etiketlerin metinleri dahil) temiz bir şekilde çekin.
#     ```html
#     <div>Başlık: <span>Alt Başlık</span></div>
#     ```
# 26. **Kısmi Nitelik Eşleştirme:** `href` niteliği `/kategori/` ile **başlayan** tüm `a` etiketlerini bulmak için nasıl bir filtreleme kullanırsınız?
# 27. **Haber Listesi Oluşturma:** Aşağıdaki HTML yapısında döngü kullanarak, her haberin başlığını ve URL'sini içeren bir Python sözlük listesi oluşturun.
#     ```html
#     <li class="haber"><a href="/detay/x">Haber X</a></li>
#     ```
# 28. **Siblings (Kardeşler):** Bir etiketi bulduktan sonra, onunla aynı seviyede olan hemen sonraki kardeşi (`next_sibling` veya `find_next_sibling()`) nasıl bulursunuz?
# 29. **Yorumları Kaldırma:** Çektiğiniz metin içinde HTML yorumları (``) varsa, `BeautifulSoup` bunları nasıl temizler veya dikkate alır?
# 30. **Veri Doğrulama:** Çektiğiniz haber başlıklarının hiçbirinin boş olmadığından emin olmak için bir Python list comprehension kodu yazın.
#
# ---
#
# ### Oturum 3 Pratikleri: `Selenium` ile Tarayıcı Otomasyonu (15 Soru)
#
# **Amaç:** WebDriver'ı başlatmak, elementleri bulmak, form doldurmak ve tarayıcı işlemlerini otomatikleştirmek.
#
# 31. **WebDriver Başlatma:** `selenium` kütüphanesinden `webdriver`'ı içe aktarın. Chrome (veya tercih ettiğiniz tarayıcı) için bir `WebDriver` nesnesi oluşturun.
# 32. **Sayfa Açma:** WebDriver'ı kullanarak `https://www.google.com/` adresini açın.
# 33. **Element Bulma (Name):** Google ana sayfasındaki arama çubuğunu `name="q"` niteliğini kullanarak bulun.
# 34. **Veri Gönderme:** Bulduğunuz arama çubuğuna `'Selenium otomasyon'` metnini gönderin.
# 35. **Tıklama (Submit):** Arama çubuğunda Enter tuşuna basmak veya arama butonuna tıklamak için gerekli olan metotlardan birini kullanın.
# 36. **CSS Selector ile Bulma:** Google arama sonuçları sayfasında, arama sonuçlarını gösteren bir başlığı (örneğin ilk sonucu) bir CSS Selector kullanarak bulun ve metnini çekin.
# 37. **Açık Bekleme (Explicit Wait):** Bir elementin sayfada **tıklanabilir** hale gelmesini beklemek için `WebDriverWait` ve `expected_conditions` kütüphanelerini nasıl kullanırsınız? (5 saniye bekleme süresi ile).
# 38. **Örtülü Bekleme (Implicit Wait):** WebDriver'ın her element bulma denemesi öncesinde 10 saniyeye kadar beklemesini ayarlamak için kullanılan metodu çağırın.
# 39. **Görünmez Çalıştırma (Headless):** Chrome'u arayüzsüz (headless) modda başlatmak için `Options` nesnesini nasıl yapılandırırsınız?
# 40. **Tümünü Bulma:** Bir sayfada sınıfı `urun-karti` olan tüm elementleri bulmak için kullanılan metodu çağırın ve sonuçları bir Python listesine atayın.
# 41. **Tarayıcıyı Kapatma:** Otomasyon işi bittiğinde tarayıcı penceresini kapatmak ve tüm oturumu sonlandırmak için kullanılan iki farklı metodu çağırın.
# 42. **`By` Sınıfı Kullanımı:** Bir elementi `By.ID` stratejisini kullanarak bulmak için gereken kodu yazın.
# 43. **Eylem Zincirleme (ActionChains):** Bir elementi sağ tıklama (context click) eylemini gerçekleştirmek için `ActionChains` sınıfını nasıl kullanırsınız?
# 44. **Hata Yönetimi (Element Yokluğu):** Sayfada bulunmayan bir elementi `find_element()` ile bulmaya çalıştığınızda fırlatılan hatayı yakalamak için `try-except` bloğunu yazın (`NoSuchElementException` kullanın).
# 45. **Sayfayı Kaydırma (Scroll):** Tarayıcı penceresini en alta kaydırmak için JavaScript kodunu `execute_script()` metodu ile nasıl çalıştırırsınız?

# %% [markdown]
# ## 🌐 Haftalık Eğitim Soruları: Flask ile Web Geliştirme (45 Adet)
#
# ### Oturum 1: Sanal Ortam, Flask Temelleri ve Jinja2 (15 Soru)
#
# #### Sanal Ortam ve Kurulum
#
# 1.  **Sanal Ortam (Virtual Environment) Nedir?** Sanal ortam kullanmanın temel amacı ve faydaları nelerdir?
# 2.  **Sanal Ortam Oluşturma:** Python'da `venv` modülünü kullanarak sanal ortamı komut satırında nasıl oluşturursunuz?
# 3.  **Sanal Ortamı Aktifleştirme:** Linux/macOS ve Windows ortamlarında sanal ortamı aktifleştirmek için kullanılan komutları yazın.
# 4.  **Flask Kurulumu:** Aktif bir sanal ortamda Flask kütüphanesini pip ile nasıl kurarsınız?
# 5.  **Bağımlılık Yönetimi:** Projenizin tüm bağımlılıklarını (Flask dahil) bir dosyaya kaydetmek ve başka bir ortamda bu dosyadan hızlıca kurmak için hangi komutları kullanırsınız?
#
# #### Flask Temelleri ve Route'lar
#
# 6.  **Flask Uygulaması Başlatma:** En temel Flask uygulamasını (`app` nesnesi) oluşturmak ve başlatmak için gereken minimum Python kodunu yazın.
# 7.  **`__name__` Değişkeni:** Flask uygulamasını oluştururken neden `Flask(__name__)` yapısı kullanılır? `__name__` değişkeni neyi ifade eder?
# 8.  **Basit Route Tanımlama:** Ana sayfa (`/`) için bir GET isteği yakalayan ve sadece `"Merhaba Flask!"` metnini döndüren bir route (`@app.route`) tanımlayın.
# 9.  **Dinamik Route:** Kullanıcı adını URL'den alıp (örn: `/kullanici/Ahmet`), `"Hoş geldin, Ahmet!"` mesajını döndüren dinamik bir route nasıl tanımlanır?
# 10. **HTTP Metodu Belirtme:** Sadece POST isteklerini kabul edecek şekilde bir route nasıl tanımlanır?
#
# #### Jinja2 Şablonları
#
# 11. **Jinja2 Nedir?** Flask'ta Jinja2 şablon motoru ne amaçla kullanılır?
# 12. **Şablon Oluşturma:** Flask'ta bir HTML şablon dosyasını (örneğin `ana.html`) yükleyip render etmek için hangi fonksiyon kullanılır?
# 13. **Değişken Gönderme:** Bir route içerisinden Jinja2 şablonuna `baslik = "Flask Uygulamam"` değişkenini nasıl gönderirsiniz?
# 14. **Base Template:** Tekrarlayan HTML yapılarını (Header, Footer, Navbar) merkezi olarak yönetmek için **base template** (temel şablon) nasıl oluşturulur ve diğer şablonlar bu temel şablondan nasıl miras alır? (`{% extends %}` ve `{% block %}` kullanılarak açıklayın.)
# 15. **Kontrol Yapıları:** Jinja2 şablonunda bir Python listesi üzerinde döngü (`for`) veya koşullu ifade (`if`) nasıl kullanılır? Basit bir örnekle açıklayın.
#
# ---
#
# ### Oturum 2: Formlar, Statik Dosyalar ve Kullanıcı Etkileşimi (15 Soru)
#
# #### Form İşlemleri (GET/POST)
#
# 16. **GET vs. POST (Formlar):** Bir formdaki veriyi URL'de görünür yapmadan göndermek için hangi HTTP metodunu kullanmalısınız ve bu metodun temel avantajı nedir?
# 17. **Formdan Veri Alma (GET):** Bir formdan gelen ve URL'de bulunan sorgu parametrelerine (query parameters) Flask'ta nasıl erişilir?
# 18. **Formdan Veri Alma (POST):** Bir formdan `POST` metoduyla gelen verilere (form body) Flask'ta nasıl erişilir?
# 19. **Form Girişi:** `kullanici_adi` adında bir form alanından gelen veriyi kontrol edip, boşsa hata mesajı, doluysa gelen veriyi yazdıran route kodunu yazın.
# 20. **Redirect (Yönlendirme):** Bir form başarıyla işlendikten sonra kullanıcıyı başka bir sayfaya (örneğin ana sayfaya) yönlendirmek için hangi fonksiyon kullanılır?
# 21. **URL Oluşturma:** Bir route fonksiyonunun adını kullanarak URL oluşturmak için hangi Flask fonksiyonu kullanılır? (Örn: `ana_sayfa` adlı fonksiyondan URL oluşturma.)
# 22. **Hata Mesajları (Flasher):** Kullanıcıya geçici bildirimler (örneğin "Giriş başarılı" veya "Hata oluştu") göstermek için Flask'ta hangi mekanizma kullanılır ve bu mesajlar şablonda nasıl gösterilir?
#
# #### Statik Dosyalar ve Medya
#
# 23. **Statik Klasörü:** Flask'ta CSS, JavaScript ve görselleri içeren dosyalar varsayılan olarak hangi klasörde tutulur?
# 24. **Statik Dosya URL'si:** Jinja2 şablonunda, `static/css/style.css` dosyasına doğru bir URL yolu oluşturmak için `url_for()` fonksiyonunu nasıl kullanırsınız?
# 25. **Dosya Yükleme (Upload):** Flask uygulamasında kullanıcıdan bir dosya (`request.files`) alıp sunucudaki bir klasöre kaydetmek için gereken temel adımları açıklayın.
#
# #### Kullanıcı Etkileşimi ve Çerezler
#
# 26. **Session (Oturum) Nedir?** Flask'ta 'session' (oturumu) ne amaçla kullanılır? Flask oturumlarının güvenliği nasıl sağlanır?
# 27. **Session Kullanımı:** Bir kullanıcının oturumuna `kullanici_id = 123` değerini nasıl eklersiniz ve bu değeri başka bir route'ta nasıl okursunuz?
# 28. **Çerez (Cookie) Kullanımı:** Bir kullanıcıya kalıcı bir çerez (`username=ali`) göndermek için hangi metot kullanılır?
# 29. **Çerez Okuma:** Gelen istekten, daha önce gönderilmiş olan `username` çerezini nasıl okursunuz?
# 30. **Çerez Silme:** Bir kullanıcının tarayıcısından belirli bir çerezi (örneğin `username`) kaldırmak için ne yapmanız gerekir?
#
# ---
#
# ### Oturum 3: Veritabanı (SQLAlchemy), API ve Dosya İşlemleri (15 Soru)
#
# #### Flask-SQLAlchemy ve ORM
#
# 31. **`Flask-SQLAlchemy` Nedir?** Bu uzantının temel amacı ve Flask uygulamalarında sağladığı kolaylıklar nelerdir?
# 32. **Veritabanı Yapılandırması:** Flask uygulamasında SQLite veritabanı dosyasının yolunu (`SQLALCHEMY_DATABASE_URI`) yapılandırma dosyasında nasıl tanımlarsınız?
# 33. **Model Tanımlama:** `Kitap` adında bir model (sınıf) oluşturun. Bu modelin `id` (PK), `baslik` (String) ve `yazar` (String) sütunlarını tanımlayın.
# 34. **Tablo Oluşturma:** Tanımlanan tüm modellerin, veritabanında ilgili tabloları oluşturması için hangi Flask komutu veya Python kodu kullanılır?
# 35. **Veri Ekleme:** Yeni bir `Kitap` nesnesi oluşturun ve bunu veritabanına kaydetmek için gereken adımları yazın.
# 36. **Tüm Veriyi Sorgulama:** `Kitap` tablosundaki tüm kitapları nasıl sorgularsınız? (`.query.all()` veya yeni sürümlerdeki karşılığı)
# 37. **Koşullu Sorgulama:** Başlığı "Python" ile başlayan tüm kitapları sorgulamak için gereken `filter()` metodunu yazın.
#
# #### Basit API Geliştirme
#
# 38. **API Route:** `/api/kitaplar` adresine bir GET isteği geldiğinde, veritabanındaki tüm kitapları çekip **JSON formatında** döndüren bir route nasıl yazılır? Hangi Flask fonksiyonu (`jsonify` veya benzeri) kullanılır?
# 39. **Tekil Kayıt API:** `/api/kitaplar/<int:id>` rotasına gelen istekte, belirtilen ID'ye sahip kitabı bulup JSON olarak döndüren route'u yazın. Kayıt bulunamazsa 404 döndürün.
# 40. **API POST (Ekleme):** `/api/kitaplar` adresine POST isteği ile gelen JSON verisinden yeni bir kitap kaydı oluşturmak için `request.get_json()` metodunu nasıl kullanırsınız?
#
# #### Dosya İşlemleri (Medya)
#
# 41. **Güvenli Dosya Adı:** Kullanıcıdan gelen dosya adlarını (örn: `çakma_dosya adı.jpg`) sunucuda kaydetmeden önce güvenli hale getirmek için hangi aracı (Flask veya harici bir kütüphane) kullanırsınız?
# 42. **Kullanıcıdan Gelen Dosyayı Kaydetme:** Kullanıcıdan gelen bir dosyayı Flask uygulamasındaki `uploads` klasörüne kaydetmek için gereken temel kodu yazın.
# 43. **Dosya URL'si (Statik Dosya Olarak Sunma):** Yüklediğiniz dosyaları (örn: `uploads/resim.jpg`) web üzerinden erişilebilir bir URL ile sunmak için nasıl bir route veya yapılandırma kullanırsınız?
# 44. **Veritabanı ve Dosya İlişkisi:** `Kitap` modeline, yüklenen bir kapak fotoğrafının dosya adını tutan bir sütun (`kapak_resmi`) ekleyin ve bir kitap kaydedilirken dosya adını veritabanına nasıl kaydettiğinizi açıklayın.
# 45. **Dosya Kontrolü:** Yüklenen bir dosyanın uzantısının (örn: `.jpg`, `.png`) izin verilen uzantılar arasında olup olmadığını kontrol etmek için nasıl bir mantık kurarsınız?

# %% [markdown]
# ## 🚀 Flask ile Web Geliştirme Proje Ödevleri (15 Adet)
#
# ### 🎯 Basit Projeler (Temel Route, Jinja2, Statik Dosyalar)
#
# #### Proje 1: Kişisel Portfolyo Sitesi
#
# | Detay | Açıklama |
# | :--- | :--- |
# | **Amaç** | Temel Flask route'ları, HTML şablonları ve statik CSS/JS dosyalarını kullanarak tek sayfalık veya çok sayfalı basit bir web sitesi oluşturmak. |
# | **Proje Yapısı** | `app.py`, `templates/index.html`, `static/css/style.css`, `static/img/profil.jpg` |
# | **Gereksinimler** | 1. Ana sayfa (`/`). 2. Hakkımda, Yetenekler ve İletişim bölümleri. 3. Statik CSS kullanarak düzenleme. 4. Jinja2 şablonu kullanarak dinamik başlık. |
# | **Genişletme** | İletişim formunu sadece bir POST isteği yakalayacak şekilde ekleyin (veriyi veritabanına kaydetmeden sadece konsola yazdırın). |
#
# #### Proje 2: To-Do Listesi (Yerel Depolama)
#
# | Detay | Açıklama |
# | :--- | :--- |
# | **Amaç** | Veritabanı kullanmadan, yapılacaklar listesini sadece oturum (Session) veya uygulama belleğinde (Python listesi) tutarak CRUD (Oluşturma, Okuma, Silme) işlemlerini yapmak. |
# | **Proje Yapısı** | `app.py`, `templates/todo.html` |
# | **Gereksinimler** | 1. Yeni görev ekleme formu (POST). 2. Mevcut görevleri listeleme (GET). 3. Görevleri oturum (session) içinde depolama. 4. Görevleri listeden silme butonu. |
# | **Genişletme** | Görevleri "Tamamlandı" olarak işaretleme özelliği ekleyin ve görev durumunu oturumda saklayın. |
#
# #### Proje 3: Temel URL Kısaltıcı (Veritabanı Yok)
#
# | Detay | Açıklama |
# | :--- | :--- |
# | **Amaç** | Rastgele kısa bir kod üretmek ve orijinal URL'i uygulama belleğinde (Python sözlüğü) saklayarak yönlendirme yapmak. |
# | **Proje Yapısı** | `app.py`, `templates/form.html`, `templates/sonuc.html` |
# | **Gereksinimler** | 1. Uzun URL'yi alan bir form. 2. Rastgele 4 karakterli benzersiz bir kod üreten fonksiyon. 3. Dinamik bir route (`/<kisa_kod>`) tanımlayıp `redirect()` kullanarak kullanıcıyı orijinal URL'ye yönlendirme. |
# | **Genişletme** | Kısa kod oluşturulduğunda kullanıcıya bu kodu ve kısaltılmış URL'yi gösterin. |
#
# ### 🛠️ Orta Düzey Projeler (SQLAlchemy, Formlar, Kimlik Doğrulama)
#
# #### Proje 4: Basit Kitaplık Uygulaması (CRUD)
#
# | Detay | Açıklama |
# | :--- | :--- |
# | **Amaç** | `Flask-SQLAlchemy` kullanarak basit bir veritabanı CRUD uygulaması geliştirmek. |
# | **Proje Yapısı** | `app.py`, `models.py`, `templates/liste.html`, `templates/ekle.html` |
# | **Gereksinimler** | 1. `Kitap` modelini (Başlık, Yazar, Yayın Yılı) tanımlayın. 2. Yeni kitap ekleme formu (POST). 3. Tüm kitapları listeleme. 4. Mevcut bir kitabı güncelleme ve silme linkleri. |
# | **Genişletme** | Kitap listesini yazar adına göre alfabetik sıralama veya yayın yılına göre filtreleme özelliği ekleyin. |
#
# #### Proje 5: Kullanıcı Kayıt ve Giriş Sistemi
#
# | Detay | Açıklama |
# | :--- | :--- |
# | **Amaç** | `Flask-SQLAlchemy` ve `session` kullanarak temel bir kimlik doğrulama sistemi kurmak. |
# | **Proje Yapısı** | `app.py`, `models.py`, `templates/kayit.html`, `templates/giris.html`, `templates/profil.html` |
# | **Gereksinimler** | 1. `Kullanici` modelini (kullanıcı adı, parola hash'i) tanımlayın. 2. Kayıt olma ve Giriş yapma route'ları. 3. Başarılı girişte `session` kullanarak kullanıcıyı oturumda tutma. 4. `@login_required` benzeri bir dekoratörle bir sayfayı sadece giriş yapmış kullanıcılara açma. |
# | **Genişletme** | Parola güvenliği için (hashing) `werkzeug.security` kullanın. |
#
# #### Proje 6: Basit Blog/Makale Uygulaması
#
# | Detay | Açıklama |
# | :--- | :--- |
# | **Amaç** | Kalıtım ve Bire-Çok ilişkisi gerektiren bir blog sistemi oluşturmak. |
# | **Proje Yapısı** | `app.py`, `models.py`, `templates/makale.html`, `templates/yeni_makale.html` |
# | **Gereksinimler** | 1. `Yazar` ve `Makale` modellerini (Bire-Çok ilişkisi) tanımlayın. 2. Yeni makale ekleme (Makale yazarı seçilebilir olmalı). 3. Tüm makalelerin listesi. 4. Makaleleri ID'sine göre tek sayfada gösterme. |
# | **Genişletme** | Makalelere yorum ekleme özelliği ekleyin (`Yorum` modeli ve Bire-Çok ilişkisi). |
#
# #### Proje 7: Dinamik Sınav Uygulaması
#
# | Detay | Açıklama |
# | :--- | :--- |
# | **Amaç** | Form ve mantık kontrolleriyle dinamik içerik sunmak. |
# | **Proje Yapısı** | `app.py`, `templates/soru.html`, `templates/sonuc.html` |
# | **Gereksinimler** | 1. Uygulama içinde bir Python listesinde 5-10 soru-cevap veri seti tutun. 2. Her soru için bir form (GET ile soru ID'sini alsın) hazırlayın. 3. Kullanıcının cevabını POST ile alıp doğru/yanlış kontrolü yapın. 4. Sonuç sayfasında toplam doğru sayısını gösterin. |
# | **Genişletme** | Soru-cevap setini bir JSON dosyasından okuyun ve `session` kullanarak kullanıcının hangi soruda kaldığını takip edin. |
#
# #### Proje 8: Basit Dosya Yükleyici
#
# | Detay | Açıklama |
# | :--- | :--- |
# | **Amaç** | Flask'ta dosya yükleme ve statik dosya sunma işlemlerini pratik etmek. |
# | **Proje Yapısı** | `app.py`, `templates/yukle.html`, `upload_folder/` |
# | **Gereksinimler** | 1. Dosya seçimi ve yükleme butonu içeren bir form. 2. Sunucuda güvenli bir dosya adı oluşturma (`werkzeug.utils.secure_filename`). 3. Yüklenen dosyayı sunucudaki bir klasöre (`uploads`) kaydetme. 4. Yüklenen dosyaların bir listesini gösterme. |
# | **Genişletme** | Yalnızca belirli dosya türlerine (örn: `.png`, `.jpg`) izin verin ve kısıtlama hatası mesajı gösterin. |
#
# ### ⭐ İleri Düzey Projeler (API, Çoklu İlişkiler, Harici API Kullanımı)
#
# #### Proje 9: Hava Durumu API Uygulaması
#
# | Detay | Açıklama |
# | :--- | :--- |
# | **Amaç** | Python `requests` kütüphanesini kullanarak harici bir API'den veri çekip Flask ile sunmak. |
# | **Proje Yapısı** | `app.py`, `templates/hava_durumu.html` |
# | **Gereksinimler** | 1. OpenWeatherMap veya benzeri bir servisten API anahtarı alın. 2. Şehir adı alan bir form. 3. Form gönderildiğinde `requests` ile API'den güncel hava durumu verisini çekin. 4. Çekilen veriyi (sıcaklık, nem vb.) Jinja2 şablonu ile kullanıcının görmesi için render edin. |
# | **Genişletme** | API isteğinde hata oluşursa (404, 500), kullanıcıya anlaşılır bir hata mesajı gösterin. |
#
# #### Proje 10: CRUD API Servisi
#
# | Detay | Açıklama |
# | :--- | :--- |
# | **Amaç** | `Flask-SQLAlchemy` kullanarak JSON veri döndüren RESTful benzeri bir API oluşturmak. |
# | **Proje Yapısı** | `app.py`, `models.py` |
# | **Gereksinimler** | 1. `Urun` modelini tanımlayın. 2. `/api/urunler` (GET) - Tüm ürünleri JSON listesi olarak döndürün (`jsonify` kullanarak). 3. `/api/urunler/<int:id>` (GET) - Belirli bir ürünü JSON olarak döndürün. 4. `/api/urunler` (POST) - Yeni ürün ekleyin (`request.get_json()` kullanarak). |
# | **Genişletme** | PUT ve DELETE metotlarını ekleyerek CRUD işlemlerini tamamlayın. |
#
# #### Proje 11: Basit Sosyal Medya Akışı
#
# | Detay | Açıklama |
# | :--- | :--- |
# | **Amaç** | Üçlü (Çoktan-Çoğa) ilişkileri modellemek ve karmaşık sorgular yazmak. |
# | **Proje Yapısı** | `app.py`, `models.py` |
# | **Gereksinimler** | 1. `Kullanici`, `Gonderi` ve **Takipçi İlişkisi** (Çoktan-Çoğa) modellerini tanımlayın. 2. Kullanıcıların birbirini takip etme/bırakma işlemlerini kaydedin. 3. Giriş yapan kullanıcının, takip ettiği kişilerin gönderilerini gösteren bir "Akış" sayfası oluşturun. |
# | **Genişletme** | Gönderilere 'Beğeni' özelliği ekleyin (Çoktan-Çoğa ilişkisi). |
#
# #### Proje 12: Basit E-Ticaret Sepeti Simülasyonu
#
# | Detay | Açıklama |
# | :--- | :--- |
# | **Amaç** | Oturum (Session) yönetimini, listeleri ve form işlemlerini birleştirmek. |
# | **Proje Yapısı** | `app.py`, `templates/urunler.html`, `templates/sepet.html` |
# | **Gereksinimler** | 1. Sabit ürün listesi (ad, fiyat) tutun. 2. Ürün sayfasında her ürünün yanında "Sepete Ekle" butonu (POST) olsun. 3. Sepet içeriğini **session** içinde bir sözlük listesi olarak saklayın. 4. Sepet sayfasında sepet içeriğini listeleme ve toplam tutarı hesaplama. |
# | **Genişletme** | Sepetteki ürün miktarını artırma/azaltma veya ürünü tamamen kaldırma özelliği ekleyin. |
#
# #### Proje 13: Dinamik Site Haritası Oluşturucu
#
# | Detay | Açıklama |
# | :--- | :--- |
# | **Amaç** | Flask'ın URL yapısını incelemek ve XML yanıtı üretmek. |
# | **Proje Yapısı** | `app.py`, `templates/sitemap.xml` |
# | **Gereksinimler** | 1. Sitenizdeki tüm route'ları (`/`, `/hakkinda`, `/iletisim`, dinamik route'lar dahil) programatik olarak listeleyin. 2. Bu route'ları kullanarak, Jinja2'de **XML şablonu** (`sitemap.xml`) render edin. 3. Route'un `Content-Type` başlığını `application/xml` olarak ayarlayın. |
# | **Genişletme** | Veritabanındaki tüm `Makale` veya `Urun` kayıtlarını da Site Haritasına dahil edin. |
#
# #### Proje 14: URL Kısaltıcı (Veritabanı Destekli)
#
# | Detay | Açıklama |
# | :--- | :--- |
# | **Amaç** | Proje 3'ü `Flask-SQLAlchemy` ile kalıcı hale getirmek ve istatistik eklemek. |
# | **Proje Yapısı** | `app.py`, `models.py`, `templates/form.html`, `templates/istatistik.html` |
# | **Gereksinimler** | 1. `URL` modelini (orijinal URL, kısa kod, **ziyaret_sayisi**) tanımlayın. 2. Yeni URL kısaltma ve yönlendirme işlemlerini veritabanı üzerinden yapın. 3. Her yönlendirmede ilgili kaydın `ziyaret_sayisi` değerini artırın. 4. İstatistik sayfasında en çok ziyaret edilen kısaltmaları listeleyin. |
# | **Genişletme** | Kısa kodun çakışma riskini azaltmak için rastgele değil, benzersizlik garantisi veren bir yöntem kullanın (örn: ID'yi base62'ye çevirme). |
#
# #### Proje 15: Kullanıcı Arayüzü ile Veritabanı Yönetimi
#
# | Detay | Açıklama |
# | :--- | :--- |
# | **Amaç** | `Flask` ile veritabanı işlemlerini, kullanıcı arayüzü (Admin Paneli benzeri) üzerinden yönetmek. |
# | **Proje Yapısı** | `app.py`, `models.py`, `templates/admin/` |
# | **Gereksinimler** | 1. Basit bir `PanelKullanicisi` login sistemi kurun. 2. Üç farklı veritabanı modelini (örn: `Kategori`, `Urun`, `Siparis`) tanımlayın. 3. Her model için ayrı bir sayfada **listeleme**, **düzenleme** ve **silme** formlarını ve route'larını oluşturun. 4. CRUD işlemlerinde başarılı/hata mesajlarını göstermek için **flashing** mekanizmasını kullanın. |
# | **Genişletme** | İki model arasında Bire-Çok ilişkisini (örn: Kategoriye göre ürün filtreleme) uygulayın. |

# %% [markdown]
# ## 🌟 İleri Düzey Projeler: İlişkisel Veritabanı, API ve Dosya İşlemleri (10 Proje)
#
# ### Proje 1: Gelişmiş E-Ticaret Katalog Yöneticisi
#
# | Detay | Açıklama |
# | :--- | :--- |
# | **Amaç** | Bire-Çok ilişkisini kullanarak ürün ve kategori yönetimini yapmak ve görsel yüklemek. |
# | **Proje Yapısı** | `app.py`, `models.py`, `templates/admin/`, `static/uploads/` |
# | **Gereksinimler** | 1. **Modeller:** `Kategori` ve `Urun` (Bire-Çok ilişkisi: Bir Kategoriye ait birden çok Ürün). 2. **Medya:** Ürün için kapak fotoğrafı yükleme alanı, fotoğrafı güvenli adla `static/uploads` klasörüne kaydetme. 3. **CRUD:** Ürün ve Kategori için ayrı ayrı CRUD sayfaları. |
# | **Özel Zorluk** | Ürün listeleme sayfasında, kategori adına göre filtreleme özelliği ekleyin (SQLAlchemy sorgusu). |
# | **Genişletme** | Ürün modeline bir `is_active` alanı ekleyip, yalnızca aktif ürünleri gösteren bir `/api/urunler` GET endpoint'i oluşturun. |
#
# ### Proje 2: Çok Kullanıcılı Blog Sistemi (Yorum ve Roller)
#
# | Detay | Açıklama |
# | :--- | :--- |
# | **Amaç** | Üçlü ilişki (Yazar, Makale, Yorum) ve temel rol yönetimi (`@login_required` ile) uygulamak. |
# | **Proje Yapısı** | `app.py`, `models.py`, `templates/`, `decorators/login.py` |
# | **Gereksinimler** | 1. **Modeller:** `Kullanici`, `Makale`, `Yorum`. `Makale` ve `Yorum`'un `Kullanici` ile Bire-Çok ilişkisi olmalı. 2. **Kimlik Doğrulama:** Kayıt/Giriş sistemi ve Makale ekleme/düzenleme sayfalarına erişimi sadece oturum açmış kullanıcılara kısıtlayın. 3. **Yetkilendirme:** Makale düzenleme butonu sadece makalenin yazarına görünmelidir. |
# | **Özel Zorluk** | Her makale sayfasında, form üzerinden yorum ekleme ve yorumları listeleme özelliği. |
# | **Genişletme** | Kullanıcılara yazar/admin rolleri atayın ve admin rolüne sahip olmayanların Makale eklemesini engelleyin. |
#
# ### Proje 3: Sosyal Etiketleme Sistemi (Çoktan-Çoğa İlişkisi)
#
# | Detay | Açıklama |
# | :--- | :--- |
# | **Amaç** | Çoktan-Çoğa ilişkisini kullanarak gönderilere etiket eklemek ve etiketlere göre filtreleme yapmak. |
# | **Proje Yapısı** | `app.py`, `models.py`, `templates/` |
# | **Gereksinimler** | 1. **Modeller:** `Gonderi` ve `Etiket`. Bu ikisi arasında bir **ilişki tablosu** (`gonderi_etiket`) tanımlayın. 2. **Ekleme Formu:** Gönderi eklerken, kullanıcının girdiği etiketleri ayırın (virgül, boşluk vb.) ve veritabanında mevcut olmayanları yeni etiket olarak oluşturun. 3. **Listeleme:** Tüm etiketleri listeleyin ve herhangi bir etikete tıklandığında sadece o etikete sahip gönderileri gösteren dinamik bir sayfa oluşturun. |
# | **Özel Zorluk** | SQLAlchemy'de `secondary` argümanını kullanarak Çoktan-Çoğa ilişkisini tanımlayın ve sorgulayın. |
# | **Genişletme** | En çok kullanılan 10 etiketi içeren bir "Etiket Bulutu" widget'ı yapın. |
#
# ### Proje 4: Çok Düzeyli Kullanıcı Takip Sistemi (API Odaklı)
#
# | Detay | Açıklama |
# | :--- | :--- |
# | **Amaç** | Çoktan-Çoğa (kendi kendine referans) ilişkisini API endpoint'leri ile yönetmek. |
# | **Proje Yapısı** | `app.py`, `models.py`, `api_routes.py` |
# | **Gereksinimler** | 1. **Model:** `Kullanici` modelini ve **kendi kendine referans veren** (self-referential) "Takip Edilenler/Takipçiler" Çoktan-Çoğa ilişkisini tanımlayın. 2. **API (POST):** `/api/takip_et` (JSON payload: `{'takip_eden_id': 1, 'takip_edilen_id': 5}`) endpoint'i ile takip kaydı oluşturun. 3. **API (GET):** `/api/kullanici/<int:id>/takip_ettikleri` endpoint'i ile bir kullanıcının takip ettiği tüm kullanıcıların listesini JSON olarak döndürün. |
# | **Özel Zorluk** | API yanıtlarında kullanıcıların sadece ID ve adını döndürün, tüm verileri değil. |
# | **Genişletme** | Takip etme/bırakma işlemleri başarılı olduğunda 201/204, hata durumunda 404/400 döndüren tam RESTful API davranışını uygulayın. |
#
# ### Proje 5: Gelişmiş Form Kontrol Sistemi (FileField ve Model İlişkisi)
#
# | Detay | Açıklama |
# | :--- | :--- |
# | **Amaç** | Flask'ta form verisi ve dosya yükleme işlemini aynı anda güvenli bir şekilde yönetmek. |
# | **Proje Yapısı** | `app.py`, `models.py`, `templates/`, `static/dokumanlar/` |
# | **Gereksinimler** | 1. **Model:** `Proje` (Adı, Açıklama, `Dokuman_Yolu`). 2. **Form:** Hem metin alanlarını hem de dosya seçme alanını (`<input type="file">`) içeren tek bir form oluşturun. 3. **İşlem:** Form POST edildiğinde, metin verisini kaydetmeden önce dosyanın **izin verilen uzantıda** olup olmadığını kontrol edin ve dosyayı sunucuya kaydedin. 4. **Veritabanı:** Dosya yolu (adıyla birlikte) veritabanına kaydedin. |
# | **Özel Zorluk** | Dosya adı oluşturmak için `secure_filename` kullanın ve dosyanın boyutu/uzantısı sınırını aşarsa kullanıcıya geri bildirim (`flash`) verin. |
# | **Genişletme** | Projelere "Durum" alanı ekleyin (örn: Başladı, Devam Ediyor, Tamamlandı) ve sayfada duruma göre renklendirme yapın. |
#
# ### Proje 6: Kendi Veritabanı Yönetim Arayüzü (Admin)
#
# | Detay | Açıklama |
# | :--- | :--- |
# | **Amaç** | Veritabanındaki tüm modellere kullanıcı arayüzü üzerinden erişim sağlayan bir yönetim paneli oluşturmak. |
# | **Proje Yapısı** | `app.py`, `models.py`, `templates/admin/` |
# | **Gereksinimler** | 1. **Admin Modeli:** Temel bir `AdminKullanicisi` login sistemi (`session` veya `flask-login` ile). 2. **Model Listeleme:** Yönetim panelinde tüm `Urun` ve `Kategori` modellerinin listesini gösteren sayfalar. 3. **CRUD Fonksiyonları:** Her model için listeleme sayfasında düzenleme ve silme linkleri (GET ve POST/DELETE metotları ile çalışmalı). |
# | **Özel Zorluk** | `flask.flash` kullanarak, her CRUD işlemi (başarılı/hatalı) sonrasında kullanıcıya geri bildirim mesajı gösterin. |
# | **Genişletme** | Listeleme sayfasına modelin herhangi bir sütununa göre sıralama (tıklanabilir başlıklar) özelliği ekleyin. |
#
# ### Proje 7: Harici API ve Veri Önbellekleme
#
# | Detay | Açıklama |
# | :--- | :--- |
# | **Amaç** | Harici API'lerden gelen veriyi `Flask-SQLAlchemy` kullanarak önbelleklemek (cache) ve sunmak. |
# | **Proje Yapısı** | `app.py`, `models.py` |
# | **Gereksinimler** | 1. **Model:** `DovizKuru` modelini (Kur Adı, Değeri, Son Güncelleme Zamanı) tanımlayın. 2. **API Çekimi:** Harici bir Döviz Kuru API'sinden (örn: fixer.io veya benzeri bir simülasyon) veri çekmek için `requests` kullanın. 3. **Önbellek Mantığı:** Veritabanındaki `Son Güncelleme Zamanı` 30 dakikadan eskiyse API'den yeni veriyi çekip güncelleyin; aksi takdirde veritabanındaki mevcut veriyi döndürün. |
# | **Özel Zorluk** | Python'da `datetime` nesneleri ile zaman farkı hesaplaması yaparak önbellek geçerliliğini kontrol edin. |
# | **Genişletme** | Belirli bir kurun geçmiş verilerini (son 7 gün) gösteren bir çizgi grafik (basit HTML tablosu bile olur) ekleyin. |
#
# ### Proje 8: Dinamik Form Oluşturucu
#
# | Detay | Açıklama |
# | :--- | :--- |
# | **Amaç** | Veritabanındaki tanımlara göre dinamik olarak HTML formları oluşturmak. |
# | **Proje Yapısı** | `app.py`, `models.py`, `templates/form_builder.html` |
# | **Gereksinimler** | 1. **Model:** `AlanTanimlama` modelini (ad, tip: 'string', 'integer', 'boolean') tanımlayın. 2. **Form Oluşturma:** Bir route'ta tüm `AlanTanimlama` kayıtlarını çekin. 3. **Jinja2:** Çekilen bu listeyi Jinja2 şablonuna göndererek, listedeki tiplere göre (string ise `<input type="text">`, boolean ise `<input type="checkbox">` vb.) dinamik olarak bir HTML formu oluşturun. |
# | **Özel Zorluk** | Oluşturulan form POST edildiğinde, gelen verinin tiplerini kontrol edin (örn: integer ise sayı olmalı) ve geçerliyse konsola yazdırın. |
# | **Genişletme** | Flask-WTF kütüphanesini kullanarak, bu dinamik alanları Flask-WTF form nesnesine dönüştürmeye çalışın. |
#
# ### Proje 9: Kullanıcı Etkinlik İzleyici (Dinamik İlişki)
#
# | Detay | Açıklama |
# | :--- | :--- |
# | **Amaç** | Kullanıcıların farklı veri modelleri üzerindeki eylemlerini kaydetmek için esnek (polimorfik benzeri) bir yapı kullanmak. |
# | **Proje Yapısı** | `app.py`, `models.py` |
# | **Gereksinimler** | 1. **Model:** `Etkinlik` modelini (Kullanıcı ID, Eylem: 'Ekleme', 'Silme', Hedef Model Adı: 'Urun', 'Makale', Hedef Kayıt ID) tanımlayın. 2. **İzleme:** Bir `Urun` eklendiğinde veya silindiğinde, bu `Etkinlik` modeline ilgili kaydı (kimin ne zaman, hangi modeli, hangi ID'deki kaydı etkilediğini) otomatik olarak kaydedin. 3. **Akış:** Tüm sistem etkinliklerini tarih sırasına göre listeleyen bir "Etkinlik Akışı" sayfası oluşturun. |
# | **Özel Zorluk** | Etkinlik Modelindeki `Hedef Model Adı` ve `Hedef Kayıt ID` alanlarını kullanarak dinamik bir ilişki simülasyonu yapın. |
# | **Genişletme** | Kullanıcının son 5 etkinliğini kendi profil sayfasında gösterin. |
#
# ### Proje 10: Üç Aşamalı Sipariş Sistemi
#
# | Detay | Açıklama |
# | :--- | :--- |
# | **Amaç** | İki farklı Çoktan-Çoğa ilişkisi ve durumu (state) yönetmek. |
# | **Proje Yapısı** | `app.py`, `models.py` |
# | **Gereksinimler** | 1. **Modeller:** `Musteri`, `Urun`, `Siparis` (Bire-Çok: Müşteri-Sipariş) ve `SiparisDetay` (Çoktan-Çoğa: Sipariş-Ürün ilişkisi ve *miktar* bilgisini tutar). 2. **Sepet:** Sepet verilerini **session**'da tutun. 3. **Sipariş Oluşturma:** Sepet onaylandığında, session'daki verileri kullanarak veritabanına yeni bir `Siparis` ve ilgili `SiparisDetay` kayıtlarını oluşturun. 4. **Durum Yönetimi:** `Siparis` modelinde 'Beklemede', 'Hazırlanıyor', 'Tamamlandı' gibi bir `durum` alanı tutun ve bir Admin sayfasında durumu güncelleme imkanı sağlayın. |
# | **Özel Zorluk** | Sipariş detay tablosunu (`SiparisDetay`) ayrı bir ORM sınıfı olarak tanımlayın ve burada *sipariş anındaki ürün fiyatını* da saklayın. |
# | **Genişletme** | Sipariş detaylarını gösteren sayfada, toplam sipariş tutarını, `SiparisDetay` kayıtlarındaki miktar * fiyat çarpımını toplayarak hesaplayın. |

# %% [markdown]
# ## 🔢 NumPy ve Dosya İşlemleri Soruları (45 Adet)
#
# ### Oturum 1: NumPy Giriş, Temel İşlemler ve Broadcasting (15 Soru)
#
# #### NumPy Temelleri ve `ndarray`
#
# 1.  **NumPy Nedir?** NumPy'ın temel amacı nedir ve Python listelerine göre en önemli iki avantajı (hız ve bellek açısından) nedir?
# 2.  **`ndarray`:** NumPy'daki ana veri yapısı olan `ndarray` (N-dimensional array) nedir?
# 3.  **İçe Aktarma:** NumPy kütüphanesini yaygın olarak kullanılan kısaltma ile nasıl içe aktarırsınız?
# 4.  **Dizi Oluşturma:** Bir Python listesini (`[1, 2, 3, 4]`) kullanarak bir NumPy dizisi (`np.array()`) nasıl oluşturulur?
# 5.  **Boyut ve Tip:** Aşağıdaki NumPy dizisinin boyutunu (`shape`) ve veri tipini (`dtype`) nasıl kontrol edersiniz?
#     ```python
#     a = np.array([[10, 20], [30, 40]])
#     ```
#
# #### Temel İşlemler ve Matris Operasyonları
#
# 6.  **Skaler Operasyon:** Bir NumPy dizisindeki tüm elemanlara aynı sayıyı (örneğin 5) eklemek için Python listelerinden farklı olarak nasıl bir yöntem kullanılır?
# 7.  **Vektörel Toplama:** Aynı boyutta (shape) olan iki NumPy dizisini (örneğin `a + b`) doğrudan topladığınızda, bu işlem eleman bazında (element-wise) mı yapılır, yoksa matris çarpımı mı yapılır?
# 8.  **Matris Çarpımı:** İki NumPy dizisi arasında standart matris çarpımı yapmak için hangi operatör veya fonksiyon kullanılır?
# 9.  **Dizinin Tipi:** Bir dizinin tüm elemanlarının veri tipini float'a (`float64`) dönüştürmek için diziyi oluştururken veya sonrasında ne yapmanız gerekir?
# 10. **Sıfır Dizisi:** 3 satır ve 4 sütundan oluşan, tüm elemanları sıfır olan bir NumPy dizisi nasıl oluşturulur?
#
# #### Broadcasting (Yayınım)
#
# 11. **Broadcasting Nedir?** NumPy'da broadcasting (yayınım) kavramını açıklayın. Bu, farklı shape'lere sahip dizilerle nasıl işlem yapmayı sağlar?
# 12. **Broadcasting Kuralı:** Shape'i `(3, 1)` olan bir dizi ile shape'i `(1, 4)` olan bir dizi toplanabilir mi? Toplanabiliyorsa, sonuç dizisinin shape'i ne olur?
# 13. **Skaler Yayınımı:** Shape'i `(5, 5)` olan bir diziye `10` skaler değerini çıkardığınızda, bu 10 değeri nasıl yayınlanır (broadcast edilir)?
# 14. **Yayınım Kontrolü:** Shape'i `(4, 3)` olan bir dizi ile shape'i `(4,)` olan bir dizi eleman bazında toplanabilir mi? Açıklayın.
# 15. **Tekrarlama:** Shape'i `(3,)` olan bir diziyi, 3 satır halinde tekrar ederek shape'i `(3, 3)` olan bir matrise dönüştürmek için hangi metodu kullanırsınız?
#
# ---
#
# ### Oturum 2: İndeksleme, Dilimleme, Yeniden Şekillendirme (15 Soru)
#
# #### İndeksleme ve Dilimleme (Slicing)
#
# 16. **Tek Eleman Erişimi:** 3 satır ve 5 sütunluk bir dizide, 2. satırın (indeks 1) 4. sütunundaki (indeks 3) elemana nasıl erişirsiniz?
# 17. **Tek Satır/Sütun Çekme:** 4x4 boyutundaki bir dizinin sadece 3. sütunundaki tüm elemanları nasıl çekersiniz?
# 18. **Dilimleme (Range):** Bir dizinin ilk 5 satırını ve son 2 sütununu içeren bir alt dizi (sub-array) nasıl oluşturulur?
# 19. **Adımlı Dilimleme:** Bir dizinin her 3. elemanını başlangıçtan sona kadar çekmek için dilimleme söz dizimi nedir?
# 20. **Ters Çevirme:** Tek boyutlu bir diziyi, elemanlarını tersten sıralı olacak şekilde nasıl dilimlersiniz?
#
# #### Koşullu İndeksleme (Boolean Masking)
#
# 21. **Boolean Maske:** Bir dizideki elemanların 10'dan büyük olup olmadığını kontrol eden bir boolean maske nasıl oluşturulur? Bu maskenin tipi nedir?
# 22. **Koşullu Çekme:** Yukarıdaki boolean maskeyi kullanarak, dizideki sadece 10'dan büyük olan elemanları içeren yeni bir dizi nasıl elde edilir?
# 23. **Koşullu Atama:** Bir dizideki değeri 0'dan küçük olan tüm elemanların değerini 0 olarak ayarlamak için boolean maskeyi nasıl kullanırsınız?
# 24. **`np.where`:** Bir dizideki çift sayıları korurken, tek sayıların yerine -1 atamak için `np.where()` fonksiyonunu nasıl kullanırsınız?
# 25. **Dinamik İndeksleme:** Tek boyutlu bir diziniz var ve başka bir dizideki indeksleri (`[0, 5, 2]`) kullanarak bu elemanlara erişmek istiyorsunuz. Bu işlemi nasıl yaparsınız?
#
# #### Dizinin Şeklini Değiştirme
#
# 26. **`reshape`:** 12 elemanlı tek boyutlu bir diziyi (shape: `(12,)`), 3 satır ve 4 sütunlu bir matrise (shape: `(3, 4)`) nasıl dönüştürürsünüz?
# 27. **Boyut Ekleme:** Bir vektörün (shape: `(5,)`) sonuna yeni bir boyut ekleyerek bir sütun vektörü (shape: `(5, 1)`) elde etmek için `np.newaxis` veya `None` anahtar kelimesini nasıl kullanırsınız?
# 28. **Düzleştirme:** Çok boyutlu bir diziyi tek boyutlu bir vektöre (düzleştirme) dönüştürmek için hangi metodu kullanırsınız?
# 29. **Transpoze:** Bir matrisin satırlarını sütun, sütunlarını satır yapmak (transpoze) için kullanılan kolay söz dizimi nedir?
# 30. **Rastgele Dizi:** 5 satır ve 5 sütundan oluşan, 0 ile 1 arasında rastgele float değerler içeren bir dizi nasıl oluşturulur?
#
# ---
#
# ### Oturum 3: İstatistik, Mantıksal İşlemler ve Dosya I/O (15 Soru)
#
# #### İstatistiksel ve Mantıksal İşlemler
#
# 31. **Ortalama:** Bir NumPy dizisindeki tüm elemanların ortalamasını (`mean`) ve standart sapmasını (`std`) hesaplamak için hangi fonksiyonlar kullanılır?
# 32. **Toplama ve Min/Max:** 5x5 boyutundaki bir dizinin **her sütununun** toplamını, minimumunu ve maksimumunu ayrı ayrı hesaplamak için `axis` parametresini nasıl kullanırsınız?
# 33. **Kümülatif Toplam:** Bir dizinin kümülatif toplamını (her elemanın kendisinden önceki elemanların toplamı ile toplamı) hesaplamak için hangi fonksiyonu kullanırsınız?
# 34. **Mantıksal İşlemler:** Bir dizideki elemanların **en az birinin** (any) belirli bir koşulu (örneğin 100'den büyük olma) sağlayıp sağlamadığını nasıl kontrol edersiniz?
# 35. **Koşul Doğrulama:** Bir dizideki elemanların **hepsinin** (all) 0'dan büyük olup olmadığını nasıl kontrol edersiniz?
#
# #### Veri Temizleme ve Eksik Değerler
#
# 36. **NaN Nedir?** NumPy ve veri biliminde `NaN` (Not a Number) neyi ifade eder ve Python'da nasıl temsil edilir?
# 37. **`np.nan` Kontrolü:** Bir dizideki hangi elemanların `NaN` olduğunu kontrol eden boolean maskeyi nasıl oluşturursunuz?
# 38. **NaN Sayısı:** Bir dizide kaç tane eksik değer (`NaN`) olduğunu saymak için `np.sum()` ve `np.isnan()` fonksiyonlarını nasıl birleştirirsiniz?
# 39. **NaN Doldurma:** Bir dizideki tüm `NaN` değerlerini, dizinin geri kalan elemanlarının ortalaması ile doldurmak için gereken adımları yazın.
# 40. **NaN Silme:** Bir dizideki herhangi bir sütununda `NaN` bulunan tüm satırları kaldırmak (silmek) için kullanılan yaygın bir yöntem nedir?
#
# #### Dosya İşlemleri (I/O)
#
# 41. **Basit Dosya Yükleme:** Virülle ayrılmış (comma-separated) veri içeren basit bir metin dosyasından (`data.txt`) verileri doğrudan bir NumPy dizisine yüklemek için hangi fonksiyon kullanılır?
# 42. **Sütun Seçimi:** Yukarıdaki metin dosyasından verileri yüklerken, sadece 1. ve 3. sütunları (0'dan başlayarak) çekmek için hangi parametre kullanılır?
# 43. **Başlık Satırı Atla:** Metin dosyasının en üstünde başlık satırı varsa, bu satırı atlayarak veri yüklemek için hangi parametre kullanılır?
# 44. **Veri Tipini Belirleme:** Metin dosyasındaki tüm verilerin `int` olarak yüklenmesini sağlamak için hangi parametre kullanılır?
# 45. **Dizi Kaydetme:** Bir NumPy dizisini, sıkıştırılmış ikili formatta (`.npz`) diske kaydetmek için kullanılan fonksiyon nedir ve bu formatın avantajı nedir?

# %% [markdown]
# ## 📊 NumPy Gerçek Veri Pratik Soruları (15 Adet)
#
# ### Pratik Hazırlık: Veri Seti Yönlendirmesi
#
# Aşağıdaki pratikler için genellikle iki popüler ve kolay erişilebilir veri setini kullanabiliriz (Python'da `numpy` veya `pandas` olmadan yüklenebilir):
#
# 1.  **İris Veri Seti (Sınıflandırma):** Bitkilerin 4 temel ölçüsünü (sepal uzunluğu/genişliği, petal uzunluğu/genişliği) içerir.
# 2.  **Boston Ev Fiyatları (Regresyon):** Çeşitli çevresel ve sosyal faktörlere dayalı ev fiyatlarını içerir.
#
# Simülasyon kolaylığı için, **İris Veri Seti'nin sayısal kısımlarını** (`sepal_length`, `sepal_width`, `petal_length`, `petal_width`) temsil eden, 150 satır ve 4 sütundan oluşan bir veri matrisi yüklediğinizi varsayın.
#
# **Örnek Yükleme İpucu (İris Verisi):**
# İris veri setinin sayısal kısmını içeren bir CSV dosyasını (`iris_data.csv`) indirerek veya oluşturarak aşağıdaki komutla yükleyebilirsiniz:
# ```python
# import numpy as np
# # np.genfromtxt, başlık satırını atlamak ve virgülle ayırmak için uygundur.
# veri = np.genfromtxt('iris_data.csv', delimiter=',', skip_header=1, dtype=float)
# # Varsayım: 'veri' dizisinin boyutu (150, 4)

# %% [markdown]
# ### Oturum 1 Pratikleri: Yükleme, Temel İşlemler ve Broadcasting (5 Soru)
#
# * **Veri Yükleme ve Boyut Kontrolü:** İris veri setini yükleyin. Yüklenen dizinin boyutunun `(150, 4)` olduğunu teyit edin ve dizinin veri tipini (`dtype`) ekrana yazdırın.
# * **Özellik Çıkarma (Feature Extraction):** İris verisinin 1. ve 3. sütunlarını içeren yeni bir alt dizi oluşturun. Bu alt dizinin shape'ini yazdırın.
# * **Broadcasting ile Ortalama Farkı:** Veri setinin her sütununun ortalamasını (`np.mean(veri, axis=0)`) hesaplayın. Bu ortalama vektörünü (shape: `(4,)`), orijinal veri matrisinden (shape: `(150, 4)`) çıkararak "Merkeze Hizalanmış Veri Matrisi"ni (Centered Data) oluşturun.
# * **Skaler Çevrim:** Sepal uzunluğu (0. sütun) ve petal uzunluğu (2. sütun) milimetre cinsinden olsun. Tüm bu değerleri santimetreye çevirmek için uygun bir skaler bölme işlemi uygulayın. İlk 5 satırı gösterin.
# * **Koşullu Başlangıç Doldurma:** Orijinal veri matrisinin boyutunda, tüm değerleri en küçük petal genişliği (3. sütun) değerine eşit olan yeni bir dizi oluşturun. Orijinal dizi ile bu yeni diziyi toplayarak sonucun ilk satırını yazdırın.
#
# ### Oturum 2 Pratikleri: İndeksleme, Dilimleme ve Yeniden Şekillendirme (5 Soru)
#
# * **Petal Filtresi:** Petal uzunluğu (2. sütun) 1.5'ten küçük olan tüm bitki kayıtlarını (tüm 4 ölçümle birlikte) Boolean Masking kullanarak filtreleyin. Filtrelenmiş kayıtların sayısını bulun.
# * **Çoklu Koşul İndeksleme:** Petal Uzunluğu 1.0 ile 1.7 arasında (dahil) olan VE Sepal Genişliği (1. sütun) 3.0'ten büyük olan tüm bitki kayıtlarını çekin.
# * **Dinamik Sıralama:** Petal Genişliği (3. sütun) değerlerine göre veri setindeki tüm satırları artan sırada (`np.argsort`) yeniden düzenleyin. En küçük Petal Genişliğine sahip ilk 3 kaydı (satırı) ekrana yazdırın.
# * **Transpoze ve Boyutlandırma:** 150x4 boyutundaki veri matrisini Transpoze edin (shape: 4x150). Ardından, elde edilen bu 4x150 matrisi, tek bir uzun vektöre (shape: `(600,)`) düzleştirin.
# * **Kare Dilimleme:** Veri setinin sadece ilk 10 satırını ve ilk 3 sütununu içeren bir alt dizi (10x3) oluşturun. Bu alt dizinin transpozesini (3x10) alın.
#
# ### Oturum 3 Pratikleri: İstatistik, Mantıksal İşlemler ve Veri Temizliği (5 Soru)
#
# * **Sütun Bazında İstatistik:** Veri setinin her bir sütunu için (4 sütun), ortalama, minimum ve maksimum değerlerini (`axis=0` kullanarak) tek tek hesaplayın ve sonuçları ayrı NumPy dizileri olarak yazdırın.
# * **Standartlaştırma (Z-Score):** Tüm veri setini (4 sütun) standartlaştırın (Normalize edin). Bunun için her bir sütun değerinden sütun ortalamasını çıkarın ve standart sapmasına bölün. Formül: $(X - \mu) / \sigma$. Standartlaştırılmış verinin ilk satırını gösterin.
# * **NaN Simülasyonu ve Sayma:** Veri setinin rastgele 10 farklı pozisyonuna `np.nan` atayarak eksik veri simülasyonu yapın. Bu dizideki toplam geçerli (NaN olmayan) eleman sayısını nasıl bulursunuz? (`np.isnan` ve `np.sum` kullanın).
# * **Ortalama ile Doldurma (Imputation):** Oluşturduğunuz eksik verili dizide, sadece 0. sütundaki (Sepal Uzunluğu) `NaN` değerlerini, o sütunun geçerli (non-NaN) elemanlarının ortalaması ile doldurun.
# * **İki Koşullu Kategorizasyon (`np.where`):** Petal Uzunluğu (2. sütun) 3.0'ten büyükse 1, değilse 0 atayan yeni bir ikili (binary) vektör oluşturun. Bu vektörün elemanlarının hepsinin 1 olup olmadığını (`np.all`) kontrol edin.

# %% [markdown]
# ## 📈 Hafta 8 Soruları: Pandas ve Veri Görselleştirme (45 Adet)
#
# ### Oturum 1: Pandas Giriş, Series, DataFrame ve Keşif (15 Soru)
#
# #### Pandas Temelleri ve Yapılar
# 1. **Pandas Nedir?** Pandas kütüphanesinin temel amacı ve veri bilimindeki önemi nedir?
# 2. **İçe Aktarma:** Pandas'ı yaygın kullanılan kısaltma ile nasıl içe aktarırsınız?
# 3. **Series Nedir?** Pandas **Series** yapısını açıklayın. Hangi iki temel bileşenden oluşur ve bir NumPy dizisinden farkı nedir?
# 4. **Series Oluşturma:** Bir Python sözlüğünü (`{'A': 10, 'B': 20, 'C': 30}`) kullanarak bir Pandas Series nesnesi nasıl oluşturulur?
# 5. **DataFrame Nedir?** Pandas **DataFrame** yapısını açıklayın. Hangi yaygın veri yapısına benzer ve hangi iki eksende etiketlenmiştir?
#
# #### Veri Yükleme ve İlk Keşif
# 6. **CSV Yükleme:** Bir CSV dosyasını (`veri.csv`) Pandas DataFrame'ine yüklemek için kullanılan temel fonksiyon nedir?
# 7. **İlk Gözlem:** Yüklediğiniz DataFrame'in ilk 5 satırını hızlıca görüntülemek için hangi metodu kullanırsınız?
# 8. **Rastgele Gözlem:** DataFrame'den rastgele 7 satır seçmek için kullanılan metot nedir?
# 9. **Yapısal Bilgi:** DataFrame'in sütun adlarını, her sütundaki NaN olmayan değer sayısını ve veri tiplerini gösteren özet bilgiyi almak için hangi metot kullanılır?
# 10. **Sütun Tipleri:** Bir DataFrame'deki tüm sütunların veri tiplerini (`dtype`) tek bir çıktı olarak nasıl görüntülersiniz?
#
# #### Betimleyici İstatistikler ve Benzersiz Değerler
# 11. **Sayısal Özet:** DataFrame'in sayısal sütunları için (sayı, ortalama, standart sapma, min/maks vb.) özet istatistikleri veren metot nedir?
# 12. **Kategorik Özet:** DataFrame'in kategorik (object/string) sütunları için (sayı, benzersiz değer sayısı, en sık görülen değer) özet istatistikleri veren metodu nasıl çağırırsınız?
# 13. **Benzersiz Değerler:** Bir sütundaki tüm **benzersiz (unique)** değerleri ve bu değerlerin **sayılarını** (frekanslarını) bulmak için kullanılan metotlar nelerdir?
# 14. **Belirli Sütun Seçimi:** Bir DataFrame'den sadece `'Maaş'` ve `'Yaş'` sütunlarını içeren yeni bir DataFrame nasıl oluşturulur?
# 15. **İndeks Sıfırlama:** DataFrame'in indeksini varsayılan sayısal indekse sıfırlamak ve eski indeksi yeni bir sütun olarak korumak için hangi metodu kullanırsınız?
#
# ---
#
# ### Oturum 2: Filtreleme, Gruplama, Eksik Veri ve İşlemler (15 Soru)
#
# #### Filtreleme ve Sorgulama
# 16. **Temel Filtreleme:** `'Yaş'` sütunundaki değeri **30'dan büyük** olan tüm kayıtları filtrelemek için gereken söz dizimi nedir?
# 17. **Çoklu Koşul:** Yaşı 25'ten küçük **VE** `'Şehir'` sütunundaki değeri `'İstanbul'` olan kayıtları filtrelemek için gereken mantıksal operatör (`&`) ile birlikte söz dizimi nedir?
# 18. **IN Operatörü:** `'Departman'` sütunundaki değeri `'İnsan Kaynakları'` veya `'Pazarlama'` olan kayıtları filtrelemek için kullanılan hızlı metot (`.isin()`) nedir?
# 19. **Metin Filtresi:** `'Ad'` sütunundaki değeri `'A'` harfiyle **başlayan** tüm kayıtları filtrelemek için `.str.startswith()` metodunu nasıl kullanırsınız?
# 20. **`loc` ve `iloc`:** `loc` ve `iloc` arasındaki temel fark nedir? DataFrame'in adlandırılmış indeksi `X` ve sütun adı `Y` olan elemana `loc` ile nasıl erişilir?
#
# #### Gruplama ve Agregasyon
# 21. **Temel Gruplama:** `'Departman'` sütununa göre gruplayarak, her departmanın ortalama maaşını nasıl hesaplarsınız?
# 22. **Çoklu Agregasyon:** `'Şehir'` sütununa göre gruplayarak, her şehirdeki `'Yaş'` sütununun hem minimumunu hem de maksimumunu (`.agg()`) nasıl hesaplarsınız?
# 23. **Sıralama:** Bir DataFrame'i önce `'Departman'` sütununa göre artan, ardından aynı departman içindeki `'Maaş'` sütununa göre azalan sırada nasıl sıralarsınız?
# 24. **Yeni Sütun Ekleme:** Mevcut `'Satış'` ve `'Maliyet'` sütunlarını kullanarak, eleman bazında çıkarma işlemi yaparak **`'NetKâr'`** adında yeni bir sütun nasıl eklersiniz?
# 25. **Uygulama (Apply) Metodu:** Bir sütundaki tüm değerlere, bu değerleri string olarak döndüren özel bir Python fonksiyonunu uygulamak için hangi metot kullanılır?
#
# #### Eksik Veri Yönetimi
# 26. **NaN Kontrolü:** DataFrame'deki her sütunda kaç adet eksik (NaN) değer olduğunu nasıl sayarsınız?
# 27. **Kayıt Silme:** Bir DataFrame'de **herhangi bir** sütununda eksik değer bulunan tüm satırları kaldırmak için kullanılan metot nedir?
# 28. **Sütun Silme:** Bir DataFrame'de eksik değerlerin bulunduğu bir sütunu (örneğin `'Notlar'`) tamamen kaldırmak için kullanılan metot nedir?
# 29. **Ortalama ile Doldurma:** Bir sütundaki (`'Maaş'`) eksik değerleri, o sütunun **ortalaması** ile doldurmak için kullanılan metot nedir?
# 30. **İleriye/Geriye Doldurma:** Bir zaman serisi verisinde, bir sütundaki eksik değerleri kendisinden hemen önceki geçerli değerle doldurmak için hangi doldurma stratejisi (`method`) kullanılır?
#
# ---
#
# ### Oturum 3: Matplotlib ve Seaborn ile Grafik Çizimi (15 Soru)
#
# #### Matplotlib Temelleri
# 31. **Matplotlib Nedir?** Matplotlib kütüphanesinin temel amacı nedir ve genellikle hangi yapıları (figür, eksenler) yönetir?
# 32. **İçe Aktarma:** Matplotlib'in yaygın olarak kullanılan `pyplot` modülünü nasıl içe aktarırsınız?
# 33. **Basit Çizgi Grafiği:** Bir NumPy dizisindeki veriyi temel bir çizgi grafiği olarak çizmek için gereken temel iki komut nedir?
# 34. **Başlık ve Etiketler:** Bir grafiğe ana başlık, x ekseni ve y ekseni etiketi eklemek için hangi `pyplot` metotları kullanılır?
# 35. **Nokta Grafiği (Scatter Plot):** İki değişken arasındaki ilişkiyi göstermek için kullanılan nokta grafiğini çizmek için hangi `pyplot` metodu kullanılır?
#
# #### Seaborn ve Veri Görselleştirme
# 36. **Seaborn Nedir?** Seaborn kütüphanesinin temel avantajı nedir ve genellikle hangi kütüphane üzerine kuruludur?
# 37. **Kategorik Çubuk Grafiği:** Bir veri setindeki `'Departman'` sütunundaki her kategorinin sayısını gösteren bir çubuk grafiği (count plot) Seaborn ile nasıl çizilir?
# 38. **Dağılım Grafiği (Histogram):** Bir sayısal sütunun (`'Maaş'`) değer dağılımını gösteren bir histogramı çizmek için kullanılan Seaborn metodu nedir?
# 39. **Kutu Grafiği (Box Plot):** Farklı grupların (örneğin departmanlar) bir sayısal değişken üzerindeki (örneğin maaş) dağılımını, aykırı değerlerini ve medyanını karşılaştırmak için hangi grafik türü (Seaborn metodu) kullanılır?
# 40. **Korelasyon Isı Haritası:** Bir DataFrame'deki tüm sayısal sütunlar arasındaki korelasyon matrisini görselleştirmek için kullanılan Seaborn metodu nedir?
#
# #### İleri Görselleştirme ve Özelleştirme
# 41. **Çoklu Grafik:** Aynı figür üzerinde, yan yana veya alt alta birden fazla küçük grafik (subplot) çizmek için `matplotlib.pyplot` içinde hangi fonksiyon kullanılır?
# 42. **Boyut Ayarı:** Matplotlib'de çizilen figürün boyutunu (örneğin 10x6 inç) ayarlamak için hangi metot kullanılır?
# 43. **Renk ve Stil:** Seaborn grafiğinde grafiğin genel stilini (örneğin koyu ızgara, beyaz arka plan) hızlıca değiştirmek için kullanılan fonksiyon nedir?
# 44. **Yoğunluk Grafiği:** İki sayısal değişkenin ortak dağılımını ve yoğunluğunu göstermek için kullanılan Seaborn metodu nedir?
# 45. **Eksen Limitleri:** Bir grafiğin x ekseninin gösterdiği aralığı (örneğin sadece 0 ile 100000 arasındaki maaşları göstermek) kısıtlamak için hangi `pyplot` metodu kullanılır?

# %% [markdown]
# # **📊 Pandas ve Görselleştirme Kod Pratikleri (15 Adet)**
# Pratik Hazırlık: Veri Seti Yönlendirmesi
# Tüm aşağıdaki pratikler için, hem Google Colab'de hem de genel veri biliminde popüler olan, Titanic Veri Setini (yolcu bilgileri ve hayatta kalma durumu) kullanacağız.
#
# Veri Yükleme Kodu (Colab veya Yerel):

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Bu, Colab'de varsayılan olarak bulunan bir veri setidir.
# Yerelde çalışıyorsanız, 'titanic.csv' dosyasını indirmeniz gerekebilir.
df = pd.read_csv('sample_data/california_housing_train.csv') # Simülasyon için başka bir hazır Colab verisi
# Ancak Titanic daha uygun olduğundan, Titanic veri setinin yüklü olduğunu varsayacağız.
# Gerçekte kullanacağınız kod:
# df = pd.read_csv('titanic.csv')

# %% [markdown]
# **Varsayım:** Sizin için daha uygun olan bir Titanic veri setini yüklediğinizi ve DataFrame adının `df` olduğunu varsayıyoruz.
#
# ### Oturum 1 & 2 Pratikleri: Pandas Temelleri, Filtreleme ve Gruplama (6 Soru)
#
# #### Senaryo 1: Veri Kalitesini Anlama
#
# * **Gözlem ve Tip Kontrolü:**
#     * `df.head()` ve `df.tail()` metotlarını kullanarak veri setinin ilk ve son 5 satırını görüntüleyin.
#     * `df.info()` metodunu çalıştırarak veri setindeki toplam satır sayısını, her sütunun adını, NaN olmayan değer sayısını ve veri tiplerini (özellikle `object` veya `float` tiplerini) inceleyin.
# * **Betimleyici İstatistikler:**
#     * `df.describe()` metodunu kullanarak sayısal sütunların (Yaş, Ücret/Fare vb.) ortalama, standart sapma, min/maks gibi özet istatistiklerini hesaplayın.
#     * Sadece `Fare` (Ücret) sütununun ortalamasını ve medyanını ayrı ayrı hesaplayın.
#
# #### Senaryo 2: Temel Filtreleme ve Seçim
#
# * **Tekil Koşul Filtresi:**
#     * `df` üzerinde, yaşı (`Age`) **18'den küçük** olan tüm yolcuları filtreleyin ve filtrelenmiş bu alt kümenin ilk 5 satırını gösterin.
#     * Filtrelenmiş bu çocuk yolcuların sayısını hesaplayın.
# * **Çoklu Koşul Filtresi:**
#     * Yaşı **40'tan büyük VEYA** bindiği sınıf (`Pclass`) **1. sınıf** olan tüm yolcuları filtreleyin.
#     * Bu filtreyi yaparken mantıksal operatör olarak **`|`** (veya) kullanın. Filtrelenmiş alt kümenin sadece `Name` ve `Age` sütunlarını görüntüleyin.
#
# #### Senaryo 3: Gruplama ve Agregasyon
#
# * **Basit Gruplama:**
#     * `Pclass` (Yolculuk Sınıfı: 1, 2, 3) sütununa göre gruplama yapın (`df.groupby()`).
#     * Her sınıftaki yolcuların ödediği `Fare` (Ücret) değerlerinin **ortalama** ve **maksimum** değerlerini hesaplayın. Sonuçları tek bir DataFrame olarak gösterin.
# * **Çoklu Kriter ve İndeks Sıfırlama:**
#     * `Sex` (Cinsiyet) ve `Embarked` (Biniş Limanı) sütunlarına göre gruplama yapın.
#     * Her grup için hayatta kalma oranını (`Survived` sütununun ortalamasını) hesaplayın.
#     * Sonuç DataFrame'in indeksini, gruplama sütunlarını normal sütunlara dönüştürerek (`.reset_index()`) sıfırlayın.
#
# ### Oturum 3 Pratikleri: Eksik Veri, Yeni Sütun ve Görselleştirme (9 Soru)
#
# #### Senaryo 4: Eksik Veri Yönetimi
#
# * **Eksik Veri İncelemesi:**
#     * `df.isnull().sum()` metodunu kullanarak her sütunda kaç adet eksik (`NaN`) değer olduğunu listeleyin.
#     * Eksik değer oranı en yüksek olan sütunu (muhtemelen `Cabin` veya `Age`) belirleyin.
# * **Doldurma ve Düşürme:**
#     * Eksik değer içeren satırların sayısının az olduğunu varsayarak, `Embarked` sütunundaki eksik değerleri o sütunun en sık görülen değeri (`.mode()`) ile doldurun.
#     * `Cabin` (Kabin) sütununu, çok fazla eksik değer içerdiği için analizden tamamen çıkarın (`.drop()`).
#
# #### Senaryo 5: Yeni Sütun Mühendisliği
#
# * **Yaş Kategorisi:**
#     * `Age` sütununu kullanarak **`Age_Group`** adında yeni bir sütun oluşturun.
#     * Yaşı 18 altı olanlar için 'Çocuk', 18-60 arası olanlar için 'Yetişkin', 60 üstü olanlar için 'Yaşlı' değerlerini atayın (`pd.cut` veya `np.where` kullanın).
# * **Aile Büyüklüğü:**
#     * Mevcut `SibSp` (Kardeş/Eş Sayısı) ve `Parch` (Ebeveyn/Çocuk Sayısı) sütunlarını toplayarak **`Family_Size`** adında yeni bir sütun oluşturun.
#     * Bu yeni sütunun ortalamasını hesaplayın.
#
# #### Senaryo 6: Matplotlib ve Seaborn ile Keşifçi Görselleştirme
#
# * **Çizgi Grafik (Matplotlib):**
#     * Basit bir `plt.plot()` kullanarak, veri setindeki ilk 50 kaydın `Fare` (Ücret) değerlerinin zaman/kayıt sırasına göre değişimini gösteren bir çizgi grafik çizin.
#     * Grafiğe 'Yolculuk Ücreti Dağılımı' başlığını ekleyin.
# * **Dağılım Grafiği (Seaborn Histogram):**
#     * `sns.histplot()` metodunu kullanarak `Age` (Yaş) sütununun değer dağılımını gösteren bir histogram çizin.
#     * Histogramın üzerine yoğunluk tahmini çizgisini (`kde=True`) ekleyin.
# * **Kategorik Çubuk Grafik (Seaborn Countplot):**
#     * `sns.countplot()` metodunu kullanarak, biniş limanlarının (`Embarked`) yolcu sayısına göre dağılımını gösteren bir çubuk grafik çizin.
#     * Grafiği `hue='Survived'` parametresi ile renklendirerek, her limandan hayatta kalan ve kalanların sayısını karşılaştırın.
# * **Kutu Grafiği (Seaborn Boxplot):**
#     * `sns.boxplot()` metodunu kullanarak, yolculuk sınıfına (`Pclass` X ekseni) göre yolcuların ödediği ücretlerin (`Fare` Y ekseni) dağılımını gösterin.
#     * Bu grafik ile aykırı değerleri (outliers) gözlemleyin.
# * **Korelasyon Isı Haritası (Heatmap):**
#     * DataFrame'in sayısal sütunları arasında korelasyon matrisini (`df.corr()`) hesaplayın.
#     * Bu korelasyon matrisini, `sns.heatmap()` metodunu kullanarak görselleştirin.
#     * Isı haritası üzerine korelasyon değerlerini (`annot=True`) ekleyerek yorumlayın.
